# %%
# TODO: add spikes analysis to code

# %%
import pandas as pd
import re
import string

# progress bar
from tqdm import tqdm
tqdm.pandas()

TOPIC_MODELLING = 0
SENTIMENT_ANALYSIS = 1

# file paths
TWEET_CORPUS_DATA_IN = "../datain/clean/largest_community_tweets.jsonl"
MAY_1_DATA_OUT = "../dataout/general/may_1.csv"
MAY_5_DATA_OUT = "../dataout/general/may_5.csv"
MAY_22_DATA_OUT = "../dataout/general/may_22.csv"
MAY_25_DATA_OUT = "../dataout/general/may_25.csv"
MAY_31_DATA_OUT = "../dataout/general/may_31.csv"

# %%
def load_data():
    '''
        Import corpus data in json format.
        Filter to have only english tweets and remove retweets.

        Returns:
            imported english, non-retweeted data
    '''
    #import the data
    filename = TWEET_CORPUS_DATA_IN
    print("\tLoading json data...")
    print("\t\tThis can take a while (about ~10 minutes on current largest community data)")
    print("\t\tGo make yourself a cup of hot thing ;)")
    data = pd.read_json(filename, lines=True)

    # clean data: remove retweets and select only english tweets
    print("\tRemoving reweets and non-english tweets...")
    data = data[~data["text"].progress_apply(lambda x: x.startswith("RT"))]
    data = data[data["lang"].progress_apply(lambda x: x == "en")]
    data = data.rename(columns={'text': 'corpus'})
    print()

    return data

# %%
def clean_tweet(tweet, remove_stop):
    '''
        Cleans tweet from hashtags, mentions, special characters, html entities, numbers,
        links, and stop words. Converts text to lower case.

        Args:
            tweet: a single tweet (String)
            remove_stop: True if stopwords should be removed and False if they should not be removed.
        Returns:
            tweet: cleaned tweet (String)
    '''
    tweet = str.lower(tweet)
    tweet = ' '.join(re.sub("(@[A-Za-z0-9_]+)|(#[A-Za-z0-9_]+)", " ", tweet).split()) # remove mentions and hashtags
    tweet = re.sub("(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w \.-]*)", "", tweet, flags=re.MULTILINE) # remove links
    tweet = re.sub("0x([\da-z\.-]+)", "", tweet, flags=re.MULTILINE) # remove addresses/pointers
    tweet = re.sub('\&\w+', "", tweet) # remove html entities (example &amp)

    return tweet

# %%
df = load_data()
df
# Out:
# 	Loading json data...
# 		This can take a while (about ~10 minutes on current largest community data)
# 		Go make yourself a cup of hot thing ;)
# 	Removing reweets and non-english tweets...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 459479/459479 [00:12<00:00, 37562.83it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 459370/459370 [00:21<00:00, 21249.53it/s]
#        lang reply_settings                                     public_metrics  \
# 0        en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1        en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2        en       everyone  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 4        en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 5        en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...     ...            ...                                                ...
# 459473   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 459474   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 459475   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 459476   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 459478   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                    corpus  possibly_sensitive  \
# 0       Good project \n#BSC @DinoSour #NFT\n@yamin_rah...               False
# 1       @AromaFinance Great project!\n\n$reset #bsc #B...               False
# 2       Such a beautiful project and congratulations t...               False
# 4       I am participating in the CryptoUltraman NFT a...               False
# 5       @apenftorg @CoinMarketCap Nice to find this pr...               False
# ...                                                   ...                 ...
# 459473  $DENA #NFT #Defi #YieldFarming\nGreat \n@lensa...               False
# 459474  @SMATOOS_now @bagasadys @airdrophunter78 @jher...               False
# 459475  @SMATOOS_now @bagasadys @airdrophunter78 @jher...               False
# 459476  @ZthCrypto @AlienWorlds How are NFT rates dete...               False
# 459478  @BilakeFinance NFT Friends ⤵️\n\n@bjkbrady @bh...               False
#
#                                                  entities  \
# 0       {'hashtags': [{'start': 14, 'end': 18, 'tag': ...
# 1       {'cashtags': [{'start': 30, 'end': 36, 'tag': ...
# 2       {'hashtags': [{'start': 198, 'end': 213, 'tag'...
# 4       {'hashtags': [{'start': 60, 'end': 78, 'tag': ...
# 5       {'cashtags': [{'start': 216, 'end': 220, 'tag'...
# ...                                                   ...
# 459473  {'hashtags': [{'start': 6, 'end': 10, 'tag': '...
# 459474  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 459475  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 459476  {'mentions': [{'start': 0, 'end': 10, 'usernam...
# 459478  {'mentions': [{'start': 31, 'end': 40, 'userna...
#
#                       created_at            author_id      conversation_id  \
# 0      2021-05-31 23:59:42+00:00  1397168952908779520  1399515966774530048
# 1      2021-05-31 23:59:40+00:00  1395244202808680448  1399313027065810944
# 2      2021-05-31 23:59:35+00:00  1397350208489463808  1399515936093204480
# 4      2021-05-31 23:58:47+00:00           2718560166  1399515734007447552
# 5      2021-05-31 23:58:44+00:00  1383794353760391168  1397848170739077120
# ...                          ...                  ...                  ...
# 459473 2021-02-01 11:31:45+00:00  1322618452108931072  1356203583193063424
# 459474 2021-02-01 11:05:55+00:00            343817344  1349729014944972800
# 459475 2021-02-01 10:49:53+00:00  1099564686788374528  1349729014944972800
# 459476 2021-02-01 09:29:19+00:00  1164164048046514176  1356157119909642240
# 459478 2021-02-01 03:58:29+00:00  1222146893473615872  1353001649384656896
#
#                                         referenced_tweets  \
# 0       [{'type': 'quoted', 'id': '1398339274953564163'}]
# 1       [{'type': 'replied_to', 'id': '139931302706581...
# 2       [{'type': 'quoted', 'id': '1399372631267287041'}]
# 4       [{'type': 'quoted', 'id': '1398277372651081732'}]
# 5       [{'type': 'replied_to', 'id': '139784817073907...
# ...                                                   ...
# 459473  [{'type': 'quoted', 'id': '1349729014944972800'}]
# 459474  [{'type': 'replied_to', 'id': '134972901494497...
# 459475  [{'type': 'replied_to', 'id': '134972901494497...
# 459476  [{'type': 'replied_to', 'id': '135615711990964...
# 459478  [{'type': 'replied_to', 'id': '135300164938465...
#
#                          id  \
# 0       1399515966774530048
# 1       1399515957362450432
# 2       1399515936093204480
# 4       1399515734007447552
# 5       1399515723274280960
# ...                     ...
# 459473  1356203583193063424
# 459474  1356197080272752640
# 459475  1356193045817872384
# 459476  1356172769424244736
# 459478  1356089513857208320
#
#                                       context_annotations  \
# 0       [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 1       [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 2       [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 4       [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 5       [{'domain': {'id': '45', 'name': 'Brand Vertic...
# ...                                                   ...
# 459473  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 459474                                                NaN
# 459475                                                NaN
# 459476                                                NaN
# 459478                                                NaN
#
#                      source  in_reply_to_user_id attachments  geo withheld
# 0           Twitter Web App                  NaN         NaN  NaN      NaN
# 1           Twitter Web App         1.390241e+18         NaN  NaN      NaN
# 2       Twitter for Android                  NaN         NaN  NaN      NaN
# 4       Twitter for Android                  NaN         NaN  NaN      NaN
# 5           Twitter Web App         1.392094e+18         NaN  NaN      NaN
# ...                     ...                  ...         ...  ...      ...
# 459473  Twitter for Android                  NaN         NaN  NaN      NaN
# 459474  Twitter for Android         3.339523e+08         NaN  NaN      NaN
# 459475  Twitter for Android         3.339523e+08         NaN  NaN      NaN
# 459476      Twitter Web App         1.138926e+18         NaN  NaN      NaN
# 459478      Twitter Web App         1.349445e+18         NaN  NaN      NaN
#
# [407489 rows x 17 columns]

# %%
'''
    Clean corpus for sentiment and topic modelling code.
'''
print("Cleaning corpus...")
# df = load_data()

# cleaning for sentiment analysis (keep stop words)
# remove_stop = False
# df['cleaned_tweet_sentiment'] = df['corpus'].progress_apply(clean_tweet, remove_stop=remove_stop)
remove_stop = True
df['cleaned_tweet_btm'] = df['corpus'].progress_apply(clean_tweet, remove_stop=remove_stop)

print("Finished cleaning corpus. The next steps will start in a few moments...")
# Out:
# Cleaning corpus...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 407489/407489 [00:26<00:00, 15198.77it/s]
# Finished cleaning corpus. The next steps will start in a few moments...

# %%
df['date'] = df['created_at'].dt.date
df['time'] = df['created_at'].dt.time

# %%
# group tweets by date and count number of entries per day
dates = df.groupby('date').count()

# %%
dates[dates['created_at']>15000]
# Out:
#              lang  reply_settings  public_metrics  corpus  possibly_sensitive  \
# date
# 2021-05-01  17097           17097           17097   17097               17097
# 2021-05-05  25580           25580           25580   25580               25580
# 2021-05-22  16535           16535           16535   16535               16535
# 2021-05-25  17292           17292           17292   17292               17292
# 2021-05-31  17893           17893           17893   17893               17893
#
#             entities  created_at  author_id  conversation_id  \
# date
# 2021-05-01     17097       17097      17097            17097
# 2021-05-05     25580       25580      25580            25580
# 2021-05-22     16535       16535      16535            16535
# 2021-05-25     17292       17292      17292            17292
# 2021-05-31     17893       17893      17893            17893
#
#             referenced_tweets     id  context_annotations  source  \
# date
# 2021-05-01               3319  17097                16712   17097
# 2021-05-05               1486  25580                25506   25580
# 2021-05-22              15700  16535                16314   16535
# 2021-05-25              11187  17292                15274   17292
# 2021-05-31              17091  17893                17355   17893
#
#             in_reply_to_user_id  attachments  geo  withheld  \
# date
# 2021-05-01                 2666           53   71         0
# 2021-05-05                18271          100  120         0
# 2021-05-22                 7960           52   70         0
# 2021-05-25                 8533           92   85         0
# 2021-05-31                 7939           64   60         0
#
#             cleaned_tweet_btm   time
# date
# 2021-05-01              17097  17097
# 2021-05-05              25580  25580
# 2021-05-22              16535  16535
# 2021-05-25              17292  17292
# 2021-05-31              17893  17893

# %%
dates
# Out:
#              lang  reply_settings  public_metrics  corpus  possibly_sensitive  \
# date
# 2021-02-01      8               8               8       8                   8
# 2021-02-02      9               9               9       9                   9
# 2021-02-03     13              13              13      13                  13
# 2021-02-04      3               3               3       3                   3
# 2021-02-05      7               7               7       7                   7
# ...           ...             ...             ...     ...                 ...
# 2021-05-27   6417            6417            6417    6417                6417
# 2021-05-28   9037            9037            9037    9037                9037
# 2021-05-29   7751            7751            7751    7751                7751
# 2021-05-30   9150            9150            9150    9150                9150
# 2021-05-31  17893           17893           17893   17893               17893
#
#             entities  created_at  author_id  conversation_id  \
# date
# 2021-02-01         8           8          8                8
# 2021-02-02         9           9          9                9
# 2021-02-03        13          13         13               13
# 2021-02-04         3           3          3                3
# 2021-02-05         7           7          7                7
# ...              ...         ...        ...              ...
# 2021-05-27      6417        6417       6417             6417
# 2021-05-28      9037        9037       9037             9037
# 2021-05-29      7751        7751       7751             7751
# 2021-05-30      9150        9150       9150             9150
# 2021-05-31     17893       17893      17893            17893
#
#             referenced_tweets     id  context_annotations  source  \
# date
# 2021-02-01                  8      8                    1       8
# 2021-02-02                  6      9                    7       9
# 2021-02-03                 12     13                    5      13
# 2021-02-04                  3      3                    1       3
# 2021-02-05                  6      7                    1       7
# ...                       ...    ...                  ...     ...
# 2021-05-27               5538   6417                 5559    6417
# 2021-05-28               8470   9037                 8497    9037
# 2021-05-29               6346   7751                 7199    7751
# 2021-05-30               7871   9150                 8459    9150
# 2021-05-31              17091  17893                17355   17893
#
#             in_reply_to_user_id  attachments  geo  withheld  \
# date
# 2021-02-01                    7            0    0         0
# 2021-02-02                    4            0    0         0
# 2021-02-03                    8            2    0         0
# 2021-02-04                    1            0    0         0
# 2021-02-05                    5            2    0         0
# ...                         ...          ...  ...       ...
# 2021-05-27                 3311           59   25         0
# 2021-05-28                 3683           54   36         0
# 2021-05-29                 3019           92   17         0
# 2021-05-30                 4352           83   31         0
# 2021-05-31                 7939           64   60         0
#
#             cleaned_tweet_btm   time
# date
# 2021-02-01                  8      8
# 2021-02-02                  9      9
# 2021-02-03                 13     13
# 2021-02-04                  3      3
# 2021-02-05                  7      7
# ...                       ...    ...
# 2021-05-27               6417   6417
# 2021-05-28               9037   9037
# 2021-05-29               7751   7751
# 2021-05-30               9150   9150
# 2021-05-31              17893  17893
#
# [120 rows x 19 columns]

# %%
may_1 = df[df['date'] == pd.to_datetime("2021-05-01")]
may_1
# Out:
# /Users/ginalamp/Workspace/Twitter_Crypto_IntraCommunity/env/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)
#        lang reply_settings                                     public_metrics  \
# 297362   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 297363   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 297364   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 297365   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 297366   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...     ...            ...                                                ...
# 314861   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 314862   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 314863   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 314864   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 314865   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                    corpus  possibly_sensitive  \
# 297362  💪Wow, $72~$1000 Airdrop, don't miss the @Crypt...               False
# 297363  @fanadisenft Thanks for the opportunity, it wi...               False
# 297364  @cybermiles I think this project will be great...               False
# 297365  A lit world of free creation that will soon be...               False
# 297366  I think this project will be great and very su...               False
# ...                                                   ...                 ...
# 314861  🚩Wow, $72~$1000 Airdrop, don't miss the @Crypt...               False
# 314862  A lit world of free creation that will soon be...               False
# 314863  A lit world of free creation that will soon be...               False
# 314864  A lit world of free creation that will soon be...               False
# 314865  A lit world of free creation that will soon be...               False
#
#                                                  entities  \
# 297362  {'hashtags': [{'start': 240, 'end': 245, 'tag'...
# 297363  {'hashtags': [{'start': 102, 'end': 106, 'tag'...
# 297364  {'hashtags': [{'start': 69, 'end': 80, 'tag': ...
# 297365  {'hashtags': [{'start': 59, 'end': 70, 'tag': ...
# 297366  {'hashtags': [{'start': 70, 'end': 81, 'tag': ...
# ...                                                   ...
# 314861  {'annotations': [{'start': 132, 'end': 150, 'p...
# 314862  {'urls': [{'start': 139, 'end': 162, 'url': 'h...
# 314863  {'urls': [{'start': 139, 'end': 162, 'url': 'h...
# 314864  {'urls': [{'start': 139, 'end': 162, 'url': 'h...
# 314865  {'urls': [{'start': 139, 'end': 162, 'url': 'h...
#
#                       created_at            author_id      conversation_id  \
# 297362 2021-05-01 23:59:48+00:00           1068724741  1388644354600816640
# 297363 2021-05-01 23:59:43+00:00  1134924652466204672  1388573491113480192
# 297364 2021-05-01 23:59:29+00:00  1388062653449441280  1387750074608865280
# 297365 2021-05-01 23:59:12+00:00  1377248305571192832  1388644201273827328
# 297366 2021-05-01 23:58:31+00:00  1388062653449441280  1388644032243552256
# ...                          ...                  ...                  ...
# 314861 2021-05-01 00:01:18+00:00  1352202408961589248  1388282342981050368
# 314862 2021-05-01 00:01:06+00:00  1387813847088599040  1388282295316979712
# 314863 2021-05-01 00:00:58+00:00  1377277543561060352  1388282259749306368
# 314864 2021-05-01 00:00:54+00:00  1117477244769718272  1388282241822859264
# 314865 2021-05-01 00:00:19+00:00  1304372870211137536  1388282096813285376
#
#                                         referenced_tweets  \
# 297362                                                NaN
# 297363  [{'type': 'replied_to', 'id': '138857349111348...
# 297364  [{'type': 'replied_to', 'id': '138775007460886...
# 297365                                                NaN
# 297366                                                NaN
# ...                                                   ...
# 314861                                                NaN
# 314862                                                NaN
# 314863                                                NaN
# 314864                                                NaN
# 314865                                                NaN
#
#                          id  \
# 297362  1388644354600816640
# 297363  1388644332576464896
# 297364  1388644275823550464
# 297365  1388644201273827328
# 297366  1388644032243552256
# ...                     ...
# 314861  1388282342981050368
# 314862  1388282295316979712
# 314863  1388282259749306368
# 314864  1388282241822859264
# 314865  1388282096813285376
#
#                                       context_annotations  \
# 297362  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 297363  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 297364  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 297365  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 297366  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# ...                                                   ...
# 314861  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 314862  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 314863  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 314864  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 314865  [{'domain': {'id': '45', 'name': 'Brand Vertic...
#
#                      source  in_reply_to_user_id attachments  geo withheld  \
# 297362  Twitter for Android                  NaN         NaN  NaN      NaN
# 297363  Twitter for Android         1.377342e+18         NaN  NaN      NaN
# 297364  Twitter for Android         9.002680e+17         NaN  NaN      NaN
# 297365      Twitter Web App                  NaN         NaN  NaN      NaN
# 297366  Twitter for Android                  NaN         NaN  NaN      NaN
# ...                     ...                  ...         ...  ...      ...
# 314861  Twitter for Android                  NaN         NaN  NaN      NaN
# 314862  Twitter for Android                  NaN         NaN  NaN      NaN
# 314863  Twitter for Android                  NaN         NaN  NaN      NaN
# 314864  Twitter for Android                  NaN         NaN  NaN      NaN
# 314865  Twitter for Android                  NaN         NaN  NaN      NaN
#
#                                         cleaned_tweet_btm        date  \
# 297362  💪wow, $72~$1000 airdrop, don't miss the airdro...  2021-05-01
# 297363  thanks for the opportunity, it will be a great...  2021-05-01
# 297364  i think this project will be great and very su...  2021-05-01
# 297365  a lit world of free creation that will soon be...  2021-05-01
# 297366  i think this project will be great and very su...  2021-05-01
# ...                                                   ...         ...
# 314861  🚩wow, $72~$1000 airdrop, don't miss the airdro...  2021-05-01
# 314862  a lit world of free creation that will soon be...  2021-05-01
# 314863  a lit world of free creation that will soon be...  2021-05-01
# 314864  a lit world of free creation that will soon be...  2021-05-01
# 314865  a lit world of free creation that will soon be...  2021-05-01
#
#             time
# 297362  23:59:48
# 297363  23:59:43
# 297364  23:59:29
# 297365  23:59:12
# 297366  23:58:31
# ...          ...
# 314861  00:01:18
# 314862  00:01:06
# 314863  00:00:58
# 314864  00:00:54
# 314865  00:00:19
#
# [17097 rows x 20 columns]

# %%
len(may_1)
# Out:
# 17097

# %%
may_5 = df[df['date'] == pd.to_datetime("2021-05-05")]
may_5
# Out:
# /Users/ginalamp/Workspace/Twitter_Crypto_IntraCommunity/env/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)
#        lang reply_settings                                     public_metrics  \
# 246864   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 246865   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 246866   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 246867   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 246868   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...     ...            ...                                                ...
# 273086   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 273087   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 273088   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 273089   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 273090   en       everyone  {'retweet_count': 1, 'reply_count': 0, 'like_c...
#
#                                                    corpus  possibly_sensitive  \
# 246864  Get one of the 100 Gen0 #KryptomonEggs\nBe the...               False
# 246865  @renft_protocol  is a multi-chain liquidity so...               False
# 246866  @renft_protocol  is a multi-chain liquidity so...               False
# 246867  @renft_protocol  is a multi-chain liquidity so...               False
# 246868  @renft_protocol  is a multi-chain liquidity so...               False
# ...                                                   ...                 ...
# 273086  Get one of the 100 Gen0 #KryptomonEggs\nBe the...               False
# 273087  A lit world of free creation that will soon be...               False
# 273088  Get one of the 100 Gen0 #KryptomonEggs\nBe the...               False
# 273089  @renft_protocol  is a multi-chain liquidity so...               False
# 273090  Click my sponsor link to claim Your Free Plati...               False
#
#                                                  entities  \
# 246864  {'hashtags': [{'start': 24, 'end': 38, 'tag': ...
# 246865  {'hashtags': [{'start': 122, 'end': 126, 'tag'...
# 246866  {'hashtags': [{'start': 122, 'end': 126, 'tag'...
# 246867  {'hashtags': [{'start': 122, 'end': 126, 'tag'...
# 246868  {'hashtags': [{'start': 122, 'end': 126, 'tag'...
# ...                                                   ...
# 273086  {'hashtags': [{'start': 24, 'end': 38, 'tag': ...
# 273087  {'hashtags': [{'start': 59, 'end': 70, 'tag': ...
# 273088  {'hashtags': [{'start': 24, 'end': 38, 'tag': ...
# 273089  {'hashtags': [{'start': 122, 'end': 126, 'tag'...
# 273090  {'hashtags': [{'start': 50, 'end': 58, 'tag': ...
#
#                       created_at            author_id      conversation_id  \
# 246864 2021-05-05 23:59:51+00:00  1302330326069329920  1390093917102563328
# 246865 2021-05-05 23:58:58+00:00            617259907  1390093694640947200
# 246866 2021-05-05 23:58:47+00:00  1012237887796940800  1390093649170468864
# 246867 2021-05-05 23:58:35+00:00  1370685806105358336  1390093600692727808
# 246868 2021-05-05 23:58:35+00:00  1366619298911772672  1390093599061135360
# ...                          ...                  ...                  ...
# 273086 2021-05-05 00:00:32+00:00            265252697  1389731703325794304
# 273087 2021-05-05 00:00:21+00:00  1205832778358644736  1389731656643366912
# 273088 2021-05-05 00:00:15+00:00  1369054047655911424  1389731630542114816
# 273089 2021-05-05 00:00:14+00:00   957346219902169088  1389731626918178816
# 273090 2021-05-05 00:00:06+00:00  1094945646761566208  1389731592801701888
#
#        referenced_tweets                   id  \
# 246864               NaN  1390093917102563328
# 246865               NaN  1390093694640947200
# 246866               NaN  1390093649170468864
# 246867               NaN  1390093600692727808
# 246868               NaN  1390093599061135360
# ...                  ...                  ...
# 273086               NaN  1389731703325794304
# 273087               NaN  1389731656643366912
# 273088               NaN  1389731630542114816
# 273089               NaN  1389731626918178816
# 273090               NaN  1389731592801701888
#
#                                       context_annotations  \
# 246864  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 246865  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 246866  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 246867  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 246868  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# ...                                                   ...
# 273086  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 273087  [{'domain': {'id': '3', 'name': 'TV Shows', 'd...
# 273088  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 273089  [{'domain': {'id': '3', 'name': 'TV Shows', 'd...
# 273090  [{'domain': {'id': '45', 'name': 'Brand Vertic...
#
#                      source  in_reply_to_user_id attachments  geo withheld  \
# 246864      Twitter Web App                  NaN         NaN  NaN      NaN
# 246865      Twitter Web App         1.370185e+18         NaN  NaN      NaN
# 246866      Twitter Web App         1.370185e+18         NaN  NaN      NaN
# 246867      Twitter Web App         1.370185e+18         NaN  NaN      NaN
# 246868  Twitter for Android         1.370185e+18         NaN  NaN      NaN
# ...                     ...                  ...         ...  ...      ...
# 273086      Twitter Web App                  NaN         NaN  NaN      NaN
# 273087      Twitter Web App                  NaN         NaN  NaN      NaN
# 273088  Twitter for Android                  NaN         NaN  NaN      NaN
# 273089   Twitter for iPhone         1.370185e+18         NaN  NaN      NaN
# 273090      Twitter Web App                  NaN         NaN  NaN      NaN
#
#                                         cleaned_tweet_btm        date  \
# 246864  get one of the 100 gen0 be the first to own a ...  2021-05-05
# 246865  is a multi-chain liquidity solution platform t...  2021-05-05
# 246866  is a multi-chain liquidity solution platform t...  2021-05-05
# 246867  is a multi-chain liquidity solution platform t...  2021-05-05
# 246868  is a multi-chain liquidity solution platform t...  2021-05-05
# ...                                                   ...         ...
# 273086  get one of the 100 gen0 be the first to own a ...  2021-05-05
# 273087  a lit world of free creation that will soon be...  2021-05-05
# 273088  get one of the 100 gen0 be the first to own a ...  2021-05-05
# 273089  is a multi-chain liquidity solution platform t...  2021-05-05
# 273090  click my sponsor link to claim your free plati...  2021-05-05
#
#             time
# 246864  23:59:51
# 246865  23:58:58
# 246866  23:58:47
# 246867  23:58:35
# 246868  23:58:35
# ...          ...
# 273086  00:00:32
# 273087  00:00:21
# 273088  00:00:15
# 273089  00:00:14
# 273090  00:00:06
#
# [25580 rows x 20 columns]

# %%
may_22 = df[df['date'] == pd.to_datetime("2021-05-22")]
may_22
# Out:
# /Users/ginalamp/Workspace/Twitter_Crypto_IntraCommunity/env/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)
#        lang reply_settings                                     public_metrics  \
# 108392   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 108393   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 108394   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 108395   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 108396   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...     ...            ...                                                ...
# 126272   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 126274   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 126279   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 126280   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 126282   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                    corpus  possibly_sensitive  \
# 108392  I am participating in @asvalabofficial airdrop...               False
# 108393  @asvalabofficial I am participating in @asvala...               False
# 108394  I am participating in @asvalabofficial airdrop...               False
# 108395  BSClaunch DEFI platform has many new solutions...               False
# 108396  @asvalabofficial “I am participating in @asval...               False
# ...                                                   ...                 ...
# 126272  I am participating in @asvalabofficial airdrop...               False
# 126274  @MODISOL_NFT Good project @Arrume2 @rumistk @R...               False
# 126279  Great project loaded with lots of prospect the...               False
# 126280  @ethernaal Great project loaded with lots of p...               False
# 126282  I am participating in @asvalabofficial airdrop...               False
#
#                                                  entities  \
# 108392  {'hashtags': [{'start': 86, 'end': 95, 'tag': ...
# 108393  {'hashtags': [{'start': 103, 'end': 112, 'tag'...
# 108394  {'hashtags': [{'start': 93, 'end': 102, 'tag':...
# 108395  {'hashtags': [{'start': 153, 'end': 163, 'tag'...
# 108396  {'hashtags': [{'start': 68, 'end': 77, 'tag': ...
# ...                                                   ...
# 126272  {'hashtags': [{'start': 83, 'end': 92, 'tag': ...
# 126274  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 126279  {'mentions': [{'start': 143, 'end': 157, 'user...
# 126280  {'mentions': [{'start': 0, 'end': 10, 'usernam...
# 126282  {'mentions': [{'start': 22, 'end': 38, 'userna...
#
#                       created_at            author_id      conversation_id  \
# 108392 2021-05-22 23:59:56+00:00  1006299619851100160  1396254534586961920
# 108393 2021-05-22 23:59:46+00:00  1006299619851100160  1395658467071840256
# 108394 2021-05-22 23:58:56+00:00  1394074739019116544  1396254283167801344
# 108395 2021-05-22 23:58:14+00:00             68267022  1396254103819358208
# 108396 2021-05-22 23:57:54+00:00  1281038430663618560  1395658467071840256
# ...                          ...                  ...                  ...
# 126272 2021-05-22 00:07:28+00:00   820681376752160768  1395894039623442432
# 126274 2021-05-22 00:05:52+00:00  1344955860624101376  1395108472094527488
# 126279 2021-05-22 00:01:20+00:00  1388861456603512832  1395892496698273792
# 126280 2021-05-22 00:01:05+00:00  1388861456603512832  1394987725913219072
# 126282 2021-05-22 00:00:28+00:00  1354612371763777536  1395892279462690816
#
#                                         referenced_tweets  \
# 108392  [{'type': 'quoted', 'id': '1395658467071840262'}]
# 108393  [{'type': 'replied_to', 'id': '139565846707184...
# 108394  [{'type': 'quoted', 'id': '1395658467071840262'}]
# 108395                                                NaN
# 108396  [{'type': 'replied_to', 'id': '139565846707184...
# ...                                                   ...
# 126272  [{'type': 'quoted', 'id': '1395658467071840262'}]
# 126274  [{'type': 'replied_to', 'id': '139510847209452...
# 126279  [{'type': 'quoted', 'id': '1394987725913219072'}]
# 126280  [{'type': 'replied_to', 'id': '139498772591321...
# 126282  [{'type': 'quoted', 'id': '1395658467071840262'}]
#
#                          id  \
# 108392  1396254534586961920
# 108393  1396254492476141568
# 108394  1396254283167801344
# 108395  1396254103819358208
# 108396  1396254023083171840
# ...                     ...
# 126272  1395894039623442432
# 126274  1395893640069718016
# 126279  1395892496698273792
# 126280  1395892433095839744
# 126282  1395892279462690816
#
#                                       context_annotations  \
# 108392  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 108393  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 108394  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 108395  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 108396  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# ...                                                   ...
# 126272  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 126274                                                NaN
# 126279  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 126280  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 126282  [{'domain': {'id': '45', 'name': 'Brand Vertic...
#
#                      source  in_reply_to_user_id  \
# 108392      Twitter Web App                  NaN
# 108393      Twitter Web App         1.389162e+18
# 108394  Twitter for Android                  NaN
# 108395      Twitter Web App                  NaN
# 108396  Twitter for Android         1.389162e+18
# ...                     ...                  ...
# 126272  Twitter for Android                  NaN
# 126274      Twitter Web App         1.395091e+18
# 126279  Twitter for Android                  NaN
# 126280  Twitter for Android         1.373252e+18
# 126282      Twitter Web App                  NaN
#
#                                       attachments  geo withheld  \
# 108392                                        NaN  NaN      NaN
# 108393                                        NaN  NaN      NaN
# 108394                                        NaN  NaN      NaN
# 108395  {'media_keys': ['3_1396252413061853191']}  NaN      NaN
# 108396                                        NaN  NaN      NaN
# ...                                           ...  ...      ...
# 126272                                        NaN  NaN      NaN
# 126274                                        NaN  NaN      NaN
# 126279                                        NaN  NaN      NaN
# 126280                                        NaN  NaN      NaN
# 126282                                        NaN  NaN      NaN
#
#                                         cleaned_tweet_btm        date  \
# 108392                     i am participating in airdrop   2021-05-22
# 108393                      i am participating in airdrop  2021-05-22
# 108394                     i am participating in airdrop   2021-05-22
# 108395  bsclaunch defi platform has many new solutions...  2021-05-22
# 108396                    “i am participating in airdrop"  2021-05-22
# ...                                                   ...         ...
# 126272                     i am participating in airdrop   2021-05-22
# 126274                                       good project  2021-05-22
# 126279  great project loaded with lots of prospect the...  2021-05-22
# 126280  great project loaded with lots of prospect the...  2021-05-22
# 126282                     i am participating in airdrop   2021-05-22
#
#             time
# 108392  23:59:56
# 108393  23:59:46
# 108394  23:58:56
# 108395  23:58:14
# 108396  23:57:54
# ...          ...
# 126272  00:07:28
# 126274  00:05:52
# 126279  00:01:20
# 126280  00:01:05
# 126282  00:00:28
#
# [16535 rows x 20 columns]

# %%
may_25 = df[df['date'] == pd.to_datetime("2021-05-25")]
may_25
# Out:
# /Users/ginalamp/Workspace/Twitter_Crypto_IntraCommunity/env/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)
#       lang reply_settings                                     public_metrics  \
# 74453   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 74454   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 74455   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 74456   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 74458   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...    ...            ...                                                ...
# 92735   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 92736   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 92737   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 92738   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 92739   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                   corpus  possibly_sensitive  \
# 74453  @nftgateio Iam participating in @nftgate.io ai...               False
# 74454  I'm Joining HSC Mainnet to Win NFT Airdrops, t...               False
# 74455  @dagifinance The project is implemented very p...               False
# 74456  I am participating in @https://twitter.com/nft...               False
# 74458  @nftgateio #NFTGATE #NFT I am participating in...               False
# ...                                                  ...                 ...
# 92735  Nice project\nThis project looks very interest...               False
# 92736  Wow Airdroo is live, This project looks very i...               False
# 92737  @nft_qr_code This project is very Good. I Love...               False
# 92738  I got in!!!! I'm registered for the upcoming @...               False
# 92739  This project looks very interesting. I am inte...               False
#
#                                                 entities  \
# 74453  {'hashtags': [{'start': 100, 'end': 108, 'tag'...
# 74454  {'hashtags': [{'start': 70, 'end': 74, 'tag': ...
# 74455  {'hashtags': [{'start': 215, 'end': 226, 'tag'...
# 74456  {'hashtags': [{'start': 102, 'end': 111, 'tag'...
# 74458  {'hashtags': [{'start': 11, 'end': 19, 'tag': ...
# ...                                                  ...
# 92735  {'mentions': [{'start': 162, 'end': 173, 'user...
# 92736  {'mentions': [{'start': 173, 'end': 182, 'user...
# 92737  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 92738  {'mentions': [{'start': 45, 'end': 58, 'userna...
# 92739  {'mentions': [{'start': 150, 'end': 162, 'user...
#
#                      created_at            author_id      conversation_id  \
# 74453 2021-05-25 23:59:52+00:00  1388124557463019520  1396718736388722688
# 74454 2021-05-25 23:59:39+00:00           2507239160  1397341623588032512
# 74455 2021-05-25 23:59:38+00:00  1353373937665675264  1394659845588979712
# 74456 2021-05-25 23:59:31+00:00  1382214302778617856  1397341590096543744
# 74458 2021-05-25 23:58:52+00:00  1366189891256684544  1396718736388722688
# ...                         ...                  ...                  ...
# 92735 2021-05-25 00:03:59+00:00  1370095944004370432  1396980328296681472
# 92736 2021-05-25 00:01:40+00:00  1322230341868814336  1396979743031906304
# 92737 2021-05-25 00:01:28+00:00  1386517838974787584  1391511576264458240
# 92738 2021-05-25 00:01:00+00:00  1374012051933253632  1396979575301844992
# 92739 2021-05-25 00:00:15+00:00  1145088991932272640  1396979390588850176
#
#                                        referenced_tweets                   id  \
# 74453  [{'type': 'replied_to', 'id': '139671873638872...  1397341681750474752
# 74454                                                NaN  1397341623588032512
# 74455  [{'type': 'replied_to', 'id': '139465984558897...  1397341622371713024
# 74456  [{'type': 'quoted', 'id': '1396718736388722689'}]  1397341590096543744
# 74458  [{'type': 'replied_to', 'id': '139671873638872...  1397341428087332864
# ...                                                  ...                  ...
# 92735  [{'type': 'quoted', 'id': '1396812892696027141'}]  1396980328296681472
# 92736  [{'type': 'quoted', 'id': '1396812892696027141'}]  1396979743031906304
# 92737  [{'type': 'replied_to', 'id': '139151157626445...  1396979695153934336
# 92738                                                NaN  1396979575301844992
# 92739  [{'type': 'quoted', 'id': '1396812892696027141'}]  1396979390588850176
#
#                                      context_annotations               source  \
# 74453  [{'domain': {'id': '45', 'name': 'Brand Vertic...   Twitter for iPhone
# 74454  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 74455  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 74456  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 74458  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# ...                                                  ...                  ...
# 92735  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 92736  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 92737                                                NaN  Twitter for Android
# 92738  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 92739  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
#
#        in_reply_to_user_id attachments  geo withheld  \
# 74453         9.657424e+17         NaN  NaN      NaN
# 74454                  NaN         NaN  NaN      NaN
# 74455         1.389575e+18         NaN  NaN      NaN
# 74456                  NaN         NaN  NaN      NaN
# 74458         9.657424e+17         NaN  NaN      NaN
# ...                    ...         ...  ...      ...
# 92735                  NaN         NaN  NaN      NaN
# 92736                  NaN         NaN  NaN      NaN
# 92737         1.388226e+18         NaN  NaN      NaN
# 92738                  NaN         NaN  NaN      NaN
# 92739                  NaN         NaN  NaN      NaN
#
#                                        cleaned_tweet_btm        date      time
# 74453        iam participating in .io airdrop # airdrops  2021-05-25  23:59:52
# 74454  i'm joining hsc mainnet to win nft airdrops, t...  2021-05-25  23:59:39
# 74455  the project is implemented very professionally...  2021-05-25  23:59:38
# 74456                       i am participating in ://://  2021-05-25  23:59:31
# 74458  i am participating in airdrop it's great so bi...  2021-05-25  23:58:52
# ...                                                  ...         ...       ...
# 92735  nice project this project looks very interesti...  2021-05-25  00:03:59
# 92736  wow airdroo is live, this project looks very i...  2021-05-25  00:01:40
# 92737  this project is very good. i love the project....  2021-05-25  00:01:28
# 92738  i got in!!!! i'm registered for the upcoming s...  2021-05-25  00:01:00
# 92739  this project looks very interesting. i am inte...  2021-05-25  00:00:15
#
# [17292 rows x 20 columns]

# %%
may_31 = df[df['date'] == pd.to_datetime("2021-05-31")]
may_31
# Out:
# /Users/ginalamp/Workspace/Twitter_Crypto_IntraCommunity/env/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)
#       lang reply_settings                                     public_metrics  \
# 0       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2       en       everyone  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 4       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 5       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...    ...            ...                                                ...
# 22751   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 22752   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 22755   en       everyone  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 22758   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 22759   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                   corpus  possibly_sensitive  \
# 0      Good project \n#BSC @DinoSour #NFT\n@yamin_rah...               False
# 1      @AromaFinance Great project!\n\n$reset #bsc #B...               False
# 2      Such a beautiful project and congratulations t...               False
# 4      I am participating in the CryptoUltraman NFT a...               False
# 5      @apenftorg @CoinMarketCap Nice to find this pr...               False
# ...                                                  ...                 ...
# 22751  Thanks for shared this wonderful opportunity. ...               False
# 22752  @Enzo__NZO Click the link to receive 1213 $NZO...               False
# 22755  @DinoSourFamily @BinanceChain Good and strong ...               False
# 22758  @asifaslam0 \n@MDALAMI16 \n@saiful04420060 \n\...               False
# 22759  Very Very good project join fast. I believe Th...               False
#
#                                                 entities  \
# 0      {'hashtags': [{'start': 14, 'end': 18, 'tag': ...
# 1      {'cashtags': [{'start': 30, 'end': 36, 'tag': ...
# 2      {'hashtags': [{'start': 198, 'end': 213, 'tag'...
# 4      {'hashtags': [{'start': 60, 'end': 78, 'tag': ...
# 5      {'cashtags': [{'start': 216, 'end': 220, 'tag'...
# ...                                                  ...
# 22751  {'urls': [{'start': 196, 'end': 219, 'url': 'h...
# 22752  {'urls': [{'start': 153, 'end': 176, 'url': 'h...
# 22755  {'hashtags': [{'start': 87, 'end': 91, 'tag': ...
# 22758  {'urls': [{'start': 77, 'end': 100, 'url': 'ht...
# 22759  {'urls': [{'start': 243, 'end': 266, 'url': 'h...
#
#                      created_at            author_id      conversation_id  \
# 0     2021-05-31 23:59:42+00:00  1397168952908779520  1399515966774530048
# 1     2021-05-31 23:59:40+00:00  1395244202808680448  1399313027065810944
# 2     2021-05-31 23:59:35+00:00  1397350208489463808  1399515936093204480
# 4     2021-05-31 23:58:47+00:00           2718560166  1399515734007447552
# 5     2021-05-31 23:58:44+00:00  1383794353760391168  1397848170739077120
# ...                         ...                  ...                  ...
# 22751 2021-05-31 00:01:54+00:00  1022339239839641600  1399154129973387264
# 22752 2021-05-31 00:01:30+00:00  1264387223329345536  1399154029071147008
# 22755 2021-05-31 00:01:13+00:00   791618831378681856  1398339274953564160
# 22758 2021-05-31 00:00:38+00:00  1245731791333289984  1399153812024086528
# 22759 2021-05-31 00:00:36+00:00  1359176039130222592  1399153805816598528
#
#                                        referenced_tweets                   id  \
# 0      [{'type': 'quoted', 'id': '1398339274953564163'}]  1399515966774530048
# 1      [{'type': 'replied_to', 'id': '139931302706581...  1399515957362450432
# 2      [{'type': 'quoted', 'id': '1399372631267287041'}]  1399515936093204480
# 4      [{'type': 'quoted', 'id': '1398277372651081732'}]  1399515734007447552
# 5      [{'type': 'replied_to', 'id': '139784817073907...  1399515723274280960
# ...                                                  ...                  ...
# 22751  [{'type': 'quoted', 'id': '1398339274953564163'}]  1399154129973387264
# 22752                                                NaN  1399154029071147008
# 22755  [{'type': 'replied_to', 'id': '139833927495356...  1399153960083066880
# 22758  [{'type': 'quoted', 'id': '1398339274953564163'}]  1399153812024086528
# 22759  [{'type': 'quoted', 'id': '1398339274953564163'}]  1399153805816598528
#
#                                      context_annotations               source  \
# 0      [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 1      [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 2      [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 4      [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 5      [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# ...                                                  ...                  ...
# 22751  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 22752  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 22755  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 22758  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 22759  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
#
#        in_reply_to_user_id attachments  geo withheld  \
# 0                      NaN         NaN  NaN      NaN
# 1             1.390241e+18         NaN  NaN      NaN
# 2                      NaN         NaN  NaN      NaN
# 4                      NaN         NaN  NaN      NaN
# 5             1.392094e+18         NaN  NaN      NaN
# ...                    ...         ...  ...      ...
# 22751                  NaN         NaN  NaN      NaN
# 22752         1.386201e+18         NaN  NaN      NaN
# 22755         1.369325e+18         NaN  NaN      NaN
# 22758         1.379746e+18         NaN  NaN      NaN
# 22759                  NaN         NaN  NaN      NaN
#
#                                        cleaned_tweet_btm        date      time
# 0                                          good project   2021-05-31  23:59:42
# 1                                  great project! $reset  2021-05-31  23:59:40
# 2      such a beautiful project and congratulations t...  2021-05-31  23:59:35
# 4      i am participating in the cryptoultraman nft a...  2021-05-31  23:58:47
# 5      nice to find this project, this project will b...  2021-05-31  23:58:44
# ...                                                  ...         ...       ...
# 22751  thanks for shared this wonderful opportunity. ...  2021-05-31  00:01:54
# 22752     click the link to receive 1213 $nzo ($500.00)   2021-05-31  00:01:30
# 22755  good and strong 💪 project guys join this airdr...  2021-05-31  00:01:13
# 22758                                     great project   2021-05-31  00:00:38
# 22759  very very good project join fast. i believe th...  2021-05-31  00:00:36
#
# [17893 rows x 20 columns]

# %%
selected_columns = ["date", "id", "corpus", "public_metrics", "entities", "author_id", "conversation_id"] # output created_at, id, and cleaned_tweets to csv
may_1.to_csv(MAY_1_DATA_OUT, columns = selected_columns)
may_5.to_csv(MAY_5_DATA_OUT, columns = selected_columns)
may_22.to_csv(MAY_22_DATA_OUT, columns = selected_columns)
may_25.to_csv(MAY_25_DATA_OUT, columns = selected_columns)
may_31.to_csv(MAY_31_DATA_OUT, columns = selected_columns)
