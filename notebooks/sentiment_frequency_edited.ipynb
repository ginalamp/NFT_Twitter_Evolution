# %% [markdown]
# # Sentiment based on tweet frequency
#
# There are 407,489 tweets that need to be split up

# %%
import os # creating directories
import pandas as pd
import matplotlib.pyplot as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# load cleaned tweet corpus data
df = pd.read_csv("../datain/sentiment/cleaned_tweets_include_stopwords_and_not_only_letters.csv")
df = df.drop("Unnamed: 0", axis=1)

# remove all null created_at values from dataframe
df = df.drop(df[df['created_at'].isnull()].index)
df = df.drop(df[df['cleaned_tweet'].isnull()].index)
# ensure that all values in created_at has 2021 (and not random strings)
df = df[df['created_at'].str.contains("2021")]

analyzer = SentimentIntensityAnalyzer()

# add polarity scores to df
# https://github.com/sidneykung/twitter_hate_speech_detection/blob/master/preprocessing/VADER_sentiment.ipynb
pol = lambda x: analyzer.polarity_scores(x)
df['polarity'] = df["cleaned_tweet"].apply(pol)

# split polarity scores into separate columns
df = pd.concat([df.drop(['polarity'], axis=1), df['polarity'].apply(pd.Series)], axis=1)

def calc_polarity(x, bound):
    if x < -0.05:
        return -1
    elif x > 0.05:
        return 1
    else:
        return 0

round_pol = lambda x: calc_polarity(x, 0.05)

# round polarity up/down
df['rounded_polarity'] = df['compound'].apply(round_pol)

# get amount of rounded negative, neutral, and positive polarity
num_rounded_sentiments = df.groupby('rounded_polarity').count()

# plot rounded negative, neutral, and positive sentiment amounts
plt.bar(num_rounded_sentiments.index, num_rounded_sentiments["compound"])
plt.title('Sentiment')
plt.xlabel('Polarity')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# load cleaned tweet corpus data
df = pd.read_csv("../datain/sentiment/cleaned_tweets_include_stopwords_and_not_only_letters.csv")
df = df.drop("Unnamed: 0", axis=1)
df
# Out:
#                        created_at                   id  \
# 0       2021-05-31 23:59:42+00:00  1399515966774530048
# 1       2021-05-31 23:59:40+00:00  1399515957362450432
# 2       2021-05-31 23:59:35+00:00  1399515936093204480
# 3       2021-05-31 23:58:47+00:00  1399515734007447552
# 4       2021-05-31 23:58:44+00:00  1399515723274280960
# ...                           ...                  ...
# 407484  2021-02-01 11:31:45+00:00  1356203583193063424
# 407485  2021-02-01 11:05:55+00:00  1356197080272752640
# 407486  2021-02-01 10:49:53+00:00  1356193045817872384
# 407487  2021-02-01 09:29:19+00:00  1356172769424244736
# 407488  2021-02-01 03:58:29+00:00  1356089513857208320
#
#                                             cleaned_tweet
# 0                                            good project
# 1                                   great project! $reset
# 2       such a beautiful project and congratulations t...
# 3       i am participating in the cryptoultraman nft a...
# 4       nice to find this project, this project will b...
# ...                                                   ...
# 407484                                        $dena great
# 407485                                    join gays $dena
# 407486                                    a great project
# 407487  how are nft rates determined? higher nft chanc...
# 407488                                     nft friends ⤵️
#
# [407489 rows x 3 columns]

# %% [markdown]
# # Clean data

# %%
# remove all null created_at values from dataframe
df = df.drop(df[df['created_at'].isnull()].index)
df = df.drop(df[df['cleaned_tweet'].isnull()].index)
# ensure that all values in created_at has 2021 (and not random strings)
df = df[df['created_at'].str.contains("2021")]

# %%
df[df["cleaned_tweet"].isnull()]
# Out:
# Empty DataFrame
# Columns: [created_at, id, cleaned_tweet]
# Index: []

# %% [markdown]
# # Sentiment: apply polarity score

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
# add polarity scores to df
# https://github.com/sidneykung/twitter_hate_speech_detection/blob/master/preprocessing/VADER_sentiment.ipynb
pol = lambda x: analyzer.polarity_scores(x)
df['polarity'] = df["cleaned_tweet"].apply(pol)
df
# Out:
#                        created_at                   id  \
# 0       2021-05-31 23:59:42+00:00  1399515966774530048
# 1       2021-05-31 23:59:40+00:00  1399515957362450432
# 2       2021-05-31 23:59:35+00:00  1399515936093204480
# 3       2021-05-31 23:58:47+00:00  1399515734007447552
# 4       2021-05-31 23:58:44+00:00  1399515723274280960
# ...                           ...                  ...
# 407484  2021-02-01 11:31:45+00:00  1356203583193063424
# 407485  2021-02-01 11:05:55+00:00  1356197080272752640
# 407486  2021-02-01 10:49:53+00:00  1356193045817872384
# 407487  2021-02-01 09:29:19+00:00  1356172769424244736
# 407488  2021-02-01 03:58:29+00:00  1356089513857208320
#
#                                             cleaned_tweet  \
# 0                                            good project
# 1                                   great project! $reset
# 2       such a beautiful project and congratulations t...
# 3       i am participating in the cryptoultraman nft a...
# 4       nice to find this project, this project will b...
# ...                                                   ...
# 407484                                        $dena great
# 407485                                    join gays $dena
# 407486                                    a great project
# 407487  how are nft rates determined? higher nft chanc...
# 407488                                     nft friends ⤵️
#
#                                                  polarity
# 0       {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'comp...
# 1       {'neg': 0.0, 'neu': 0.313, 'pos': 0.687, 'comp...
# 2       {'neg': 0.0, 'neu': 0.463, 'pos': 0.537, 'comp...
# 3       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4       {'neg': 0.0, 'neu': 0.659, 'pos': 0.341, 'comp...
# ...                                                   ...
# 407484  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...
# 407485  {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'comp...
# 407486  {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'comp...
# 407487  {'neg': 0.149, 'neu': 0.601, 'pos': 0.251, 'co...
# 407488  {'neg': 0.0, 'neu': 0.617, 'pos': 0.383, 'comp...
#
# [406631 rows x 4 columns]

# %%
# split polarity scores into separate columns
df = pd.concat([df.drop(['polarity'], axis=1), df['polarity'].apply(pd.Series)], axis=1)
df
# Out:
#                        created_at                   id  \
# 0       2021-05-31 23:59:42+00:00  1399515966774530048
# 1       2021-05-31 23:59:40+00:00  1399515957362450432
# 2       2021-05-31 23:59:35+00:00  1399515936093204480
# 3       2021-05-31 23:58:47+00:00  1399515734007447552
# 4       2021-05-31 23:58:44+00:00  1399515723274280960
# ...                           ...                  ...
# 407484  2021-02-01 11:31:45+00:00  1356203583193063424
# 407485  2021-02-01 11:05:55+00:00  1356197080272752640
# 407486  2021-02-01 10:49:53+00:00  1356193045817872384
# 407487  2021-02-01 09:29:19+00:00  1356172769424244736
# 407488  2021-02-01 03:58:29+00:00  1356089513857208320
#
#                                             cleaned_tweet    neg    neu  \
# 0                                            good project  0.000  0.256
# 1                                   great project! $reset  0.000  0.313
# 2       such a beautiful project and congratulations t...  0.000  0.463
# 3       i am participating in the cryptoultraman nft a...  0.000  1.000
# 4       nice to find this project, this project will b...  0.000  0.659
# ...                                                   ...    ...    ...
# 407484                                        $dena great  0.000  0.196
# 407485                                    join gays $dena  0.000  0.476
# 407486                                    a great project  0.000  0.328
# 407487  how are nft rates determined? higher nft chanc...  0.149  0.601
# 407488                                     nft friends ⤵️  0.000  0.617
#
#           pos  compound
# 0       0.744    0.4404
# 1       0.687    0.6588
# 2       0.537    0.9677
# 3       0.000    0.0000
# 4       0.341    0.8860
# ...       ...       ...
# 407484  0.804    0.6249
# 407485  0.524    0.2960
# 407486  0.672    0.6249
# 407487  0.251    0.3736
# 407488  0.383    0.4767
#
# [406631 rows x 7 columns]

# %%
avg_sentiment = df['compound'].mean()
avg_sentiment
# Out:
# 0.5529666911770131

# %% [markdown]
# ## Sentiment: round polarity

# %%
def calc_polarity(x, bound):
    if x < -0.05:
        return -1
    elif x > 0.05:
        return 1
    else:
        return 0

round_pol = lambda x: calc_polarity(x, 0.05)

# %%
# round polarity up/down
df['rounded_polarity'] = df['compound'].apply(round_pol)
df
# Out:
#                        created_at                   id  \
# 0       2021-05-31 23:59:42+00:00  1399515966774530048
# 1       2021-05-31 23:59:40+00:00  1399515957362450432
# 2       2021-05-31 23:59:35+00:00  1399515936093204480
# 3       2021-05-31 23:58:47+00:00  1399515734007447552
# 4       2021-05-31 23:58:44+00:00  1399515723274280960
# ...                           ...                  ...
# 407484  2021-02-01 11:31:45+00:00  1356203583193063424
# 407485  2021-02-01 11:05:55+00:00  1356197080272752640
# 407486  2021-02-01 10:49:53+00:00  1356193045817872384
# 407487  2021-02-01 09:29:19+00:00  1356172769424244736
# 407488  2021-02-01 03:58:29+00:00  1356089513857208320
#
#                                             cleaned_tweet    neg    neu  \
# 0                                            good project  0.000  0.256
# 1                                     great project reset  0.000  0.328
# 2       beautiful project congratulations whole team h...  0.000  0.251
# 3              participating cryptoultraman airdrop round  0.000  1.000
# 4       nice find project project great invite many pe...  0.000  0.467
# ...                                                   ...    ...    ...
# 407484                                         dena great  0.000  0.196
# 407485                                     join gays dena  0.000  0.476
# 407486                                      great project  0.000  0.196
# 407487  rates determined higher chance worse low chanc...  0.252  0.340
# 407488                                            friends  0.000  0.000
#
#           pos  compound  rounded_polarity
# 0       0.744    0.4404                 1
# 1       0.672    0.6249                 1
# 2       0.749    0.9677                 1
# 3       0.000    0.0000                 0
# 4       0.533    0.8860                 1
# ...       ...       ...               ...
# 407484  0.804    0.6249                 1
# 407485  0.524    0.2960                 1
# 407486  0.804    0.6249                 1
# 407487  0.408    0.2960                 1
# 407488  1.000    0.4767                 1
#
# [406031 rows x 8 columns]

# %%
# plot rounded polarity
plt.plot(df.index, df['rounded_polarity'].sort_values())
plt.title('Largest community Sentiment Analysis using Vader')
plt.ylabel('Polarity')
plt.xlabel('Tweets')
# Out:
# Text(0.5, 0, 'Tweets')

# %%
# get amount of rounded negative, neutral, and positive polarity
num_rounded_sentiments = df.groupby('rounded_polarity').count()
num_rounded_sentiments
# Out:
#                   created_at      id  cleaned_tweet     neg     neu     pos  \
# rounded_polarity
# -1                      3289    3289           3289    3289    3289    3289
#  0                     64428   64428          64428   64428   64428   64428
#  1                    338314  338314         338314  338314  338314  338314
#
#                   compound
# rounded_polarity
# -1                    3289
#  0                   64428
#  1                  338314

# %%
# plot rounded negative, neutral, and positive sentiment amounts
plt.bar(num_rounded_sentiments.index, num_rounded_sentiments["compound"])
plt.title('Sentiment')
plt.xlabel('Polarity')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
def calc_polarity(x, bound):
    if x < -0.05:
        return -1
    elif x > 0.05:
        return 1
    else:
        return 0

def get_avg_sentiment(file_name):
    # load cleaned tweet corpus data
    #df = pd.read_csv("../datain/sentiment/cleaned_tweets_include_stopwords_and_not_only_letters.csv")
    df = pd.read_csv(file_name)
    df = df.drop("Unnamed: 0", axis=1)

    # remove all null created_at values from dataframe
    df = df.drop(df[df['created_at'].isnull()].index)
    df = df.drop(df[df['cleaned_tweet'].isnull()].index)
    # ensure that all values in created_at has 2021 (and not random strings)
    df = df[df['created_at'].str.contains("2021")]

    analyzer = SentimentIntensityAnalyzer()

    # add polarity scores to df
    # https://github.com/sidneykung/twitter_hate_speech_detection/blob/master/preprocessing/VADER_sentiment.ipynb
    pol = lambda x: analyzer.polarity_scores(x)
    df['polarity'] = df["cleaned_tweet"].apply(pol)

    # split polarity scores into separate columns
    df = pd.concat([df.drop(['polarity'], axis=1), df['polarity'].apply(pd.Series)], axis=1)

    avg_sentiment = df['compound'].mean()
    print(file_name, " has avg sentiment: ", avg_sentiment)
    return avg_sentiment

# %%
get_avg_sentiment("../datain/sentiment/cleaned_tweets_no_cleaning.csv")
# Out:
# ../datain/sentiment/cleaned_tweets_no_cleaning.csv  has avg sentiment:  0.5579341501242977
# 0.5579341501242977

# %%
get_avg_sentiment("../datain/sentiment/cleaned_tweets_include_stopwords_and_not_only_letters.csv")
get_avg_sentiment("../datain/sentiment/cleaned_tweets_no_stopwords_and_only_letters.csv")
# Out:
# ../datain/sentiment/cleaned_tweets_include_stopwords_and_not_only_letters.csv  has avg sentiment:  0.5529666911770131
# ../datain/sentiment/cleaned_tweets_no_stopwords_and_only_letters.csv  has avg sentiment:  0.5444592885764881
# 0.5444592885764881
