# %% [markdown]
# # Sentiment Analysis on Specific Topics
#
# Sentiment analysis per topic.
# Automated and step-by step version.

# %%
# dependencies - install first time using this notebook
# !pip3 install vaderSentiment
# !pip3 install --upgrade pip
# !pip3 install xlrd
# !pip3 install openpyxl

import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# %% [markdown]
# # Sentiment Automation
#
# Run the below block if you want everything to be done automatically all at once.
# It will output the graphs into `dataout/sentiment/*`
#
# If you want a step-by-step understanding, then see the code below this block.

# %%
def df_setup():
    # read in data produced by topic_modelling.ipynb
    df = pd.read_csv('../datain/sentiment/grouped-by-topic_with_date.csv')
    df = df[['Unnamed: 0', 'created_at', 'maxtopic', 'corpus', "cleaned_tweet"]].copy()
    df = df.rename({'Unnamed: 0': 'tweet_index'}, axis=1)
    
    # remove any null created_at values from dataframe
    df = df.drop(df[df['created_at'].isnull()].index)
    # ensure that all values in created_at has 2021 (and not random strings)
    df = df[df['created_at'].str.contains("2021")]
    
    # split created_at into date and time columns
    #https://intellipaat.com/community/13909/python-how-can-i-split-a-column-with-both-date-and-time-e-g-2019-07-02-00-12-32-utc-into-two-separate-columns
    df['created_at'] = pd.to_datetime(df['created_at'])
    df['date'] = df['created_at'].dt.date
    df['time'] = df['created_at'].dt.time
    
    return df
    
def sentiment_analysis_per_topic(df, topic):
    # filter df to only have data for the given topic
    df = df[df["maxtopic"] == topic]
    
    # get polarity scores per tweet
    analyzer = SentimentIntensityAnalyzer()
    for tweet in df["corpus"]:
        vs = analyzer.polarity_scores(tweet)
        
    #https://github.com/sidneykung/twitter_hate_speech_detection/blob/master/preprocessing/VADER_sentiment.ipynb
    pol = lambda x: analyzer.polarity_scores(x)
    df['Polarity'] = df['corpus'].apply(pol)
    
    df = pd.concat([df.drop(['Polarity'], axis=1), df['Polarity'].apply(pd.Series)], axis=1)
    # plot first sentiment
    plot_sentiment(df, topic)
    
    # plot 2nd sentiment
    round_pol = lambda x: calc_pol(x, 0.05)
    df['Polarity'] = df['compound'].apply(round_pol)
    plot_sentiment2(df, topic)
    
    # plot 3rd sentiment
    sentiments = df.groupby('Polarity').count()
    plot_sentiment3(sentiments, topic)
    
    # group tweets by date
    dates = df.groupby('date').count()
    dates['day'] = ''
    for i in range(0, len(dates.index)):
        dates['day'][i] = dates.index[i].day
    # plot tweet frequency 
    plot_frequency_time(dates, topic)
    
    # get average tweet sentiment for a time period
    sumsentiment = 0
    count = 0
    for i in range(len(df.index)):
        if df['date'].iloc[i] == df['date'].iloc[0]:
            sumsentiment += df['compound'].iloc[i]
            count += 1
    avg = sumsentiment / count
    #calculate average sentiment per day
    #https://stackoverflow.com/questions/67899247/compute-column-average-based-on-conditions-pandas
    df_avg = df.groupby(['date'], as_index=False)['compound'].mean()
    
    #add day from date as separate column
    df_avg['day'] = ''
    for i in range(0, len(df_avg.index)):
        df_avg['day'][i] = df_avg['date'][i].day

    #plot average sentiment over time
    plot_sentiment_average_time(df_avg, topic)


def plot_sentiment(df, topic):
    plt.plot(df.index, df['compound'].sort_values())
    plt.title('Topic {}: Sentiment Analysis using Vader'.format(topic))
    plt.ylabel('Polarity')
    plt.xlabel('Tweets')
    plt.savefig('../dataout/sentiment/Topic{}_sentiment1.jpeg'.format(topic))
    plt.close()

def plot_sentiment2(df, topic):
    plt.plot(df.index, df['Polarity'].sort_values())
    plt.title('Topic {}: Sentiment Analysis using Vader'.format(topic))
    plt.ylabel('Polarity')
    plt.xlabel('Tweets')
    plt.savefig('../dataout/sentiment/Topic{}_sentiment2.jpeg'.format(topic))
    plt.close()

def plot_sentiment3(sentiments, topic):
    plt.bar(sentiments.index, sentiments["compound"])
    plt.title('Topic {}: Sentiment Polarity Difference'.format(topic))
    plt.xlabel('Polarity')
    plt.ylabel('Count')
    plt.savefig('../dataout/sentiment/Topic{}_sentiment3.jpeg'.format(topic))
    plt.close()

def plot_frequency_time(dates, topic):
    #plot tweet frequency over time
    plt.plot(dates['day'], dates['cleaned_tweet'])
    plt.title('Topic {}: Tweet Frequency'.format(topic))
    plt.xlabel('Day of May 2021')
    plt.ylabel('Count of Topic4 Tweets')
    plt.savefig('../dataout/sentiment/Topic{}_frequency.jpeg'.format(topic))
    plt.close()

def plot_sentiment_average_time(df_avg, topic):
    plt.plot(df_avg['day'], df_avg['compound'])
    plt.title('Topic {}: Sentiment Over Time'.format(topic))
    plt.ylabel('Average Polarity')
    plt.xlabel('Day of May 2021')
    plt.savefig('../dataout/sentiment/Topic{}_sentiment4_time.jpeg'.format(topic))
    plt.close()

def calc_pol(x, bound):
    if x < -0.05:
        return -1
    elif x > 0.05:
        return 1
    else:
        return 0

# run for all topic
df = df_setup()
for topic in range(20):
    sentiment_analysis_per_topic(df, topic)
    
# run for one topic
# sentiment_analysis_per_topic(df, 4)
# Out:
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day

# %% [markdown]
# # Sentiment analysis step by step
#
# This is the above code step by step (you can see the dataframes being outputted step by step, etc)

# %%
# read in data produced by topic_modelling.ipynb
df = pd.read_csv('../datain/sentiment/grouped-by-topic_with_date.csv')
df = df[['Unnamed: 0', 'created_at', 'maxtopic', 'corpus', "cleaned_tweet"]].copy()
df = df.rename({'Unnamed: 0': 'tweet_index'}, axis=1)
df
# Out:
#        tweet_index           created_at  maxtopic  \
# 0            20961  2021-05-26 06:34:56         0
# 1             6759  2021-05-30 06:36:50         0
# 2             5260  2021-05-30 16:29:15         0
# 3            16594  2021-05-27 08:42:19         0
# 4            16601  2021-05-27 08:37:47         0
# ...            ...                  ...       ...
# 30519        26959  2021-05-25 00:49:49       100
# 30520        10319  2021-05-29 01:20:58       100
# 30521        16463  2021-05-27 09:34:19       100
# 30522        17895  2021-05-26 20:52:52       100
# 30523        16290  2021-05-27 10:52:49       100
#
#                                                   corpus  \
# 0      Our new favorite hash tag is #trapdontshill\n\...
# 1      @dikparkes Watch PUMP #NFT video!🤑\nLets re-se...
# 2      @pranksyNFT @BoredApeYC @MeebitsDAO Hope hand ...
# 3      You want us to check your #NFTs. Drop them her...
# 4      @paris_museum These are the first 4 pieces min...
# ...                                                  ...
# 30519  #Crypto #wallet / #domain AND #Instagram page ...
# 30520  #NFT &amp; #Polkadot or #NFTCommunity \nand @P...
# 30521                                        What is nft
# 30522  @MattTea5 what's an nft\nᵃᵐ ⁱ ᵈᵒⁱⁿᵍ ⁱᵗ ʳⁱᵍʰᵗ ?...
# 30523  DO WE #catecoin OR #Dogecoin ?\n#cryptocurrenc...
#
#                                            cleaned_tweet
# 0                           our new favorite hash tag is
# 1                watch pump video lets re sell this girl
# 2      hope hand painted oil painting splash ink art ...
# 3      you want us to check your drop them here follo...
# 4      these are the first pieces minted in my vast c...
# ...                                                  ...
# 30519  and page with followers in the space marlon br...
# 30520                                             or and
# 30521                                        what is nft
# 30522                                      what s an nft
# 30523                                           do we or
#
# [30524 rows x 5 columns]

# %%
# remove any null created_at values from dataframe
df = df.drop(df[df['created_at'].isnull()].index)
# ensure that all values in created_at has 2021 (and not random strings)
df = df[df['created_at'].str.contains("2021")]
df
# Out:
#        tweet_index           created_at  maxtopic  \
# 0            20961  2021-05-26 06:34:56         0
# 1             6759  2021-05-30 06:36:50         0
# 2             5260  2021-05-30 16:29:15         0
# 3            16594  2021-05-27 08:42:19         0
# 4            16601  2021-05-27 08:37:47         0
# ...            ...                  ...       ...
# 30519        26959  2021-05-25 00:49:49       100
# 30520        10319  2021-05-29 01:20:58       100
# 30521        16463  2021-05-27 09:34:19       100
# 30522        17895  2021-05-26 20:52:52       100
# 30523        16290  2021-05-27 10:52:49       100
#
#                                                   corpus  \
# 0      Our new favorite hash tag is #trapdontshill\n\...
# 1      @dikparkes Watch PUMP #NFT video!🤑\nLets re-se...
# 2      @pranksyNFT @BoredApeYC @MeebitsDAO Hope hand ...
# 3      You want us to check your #NFTs. Drop them her...
# 4      @paris_museum These are the first 4 pieces min...
# ...                                                  ...
# 30519  #Crypto #wallet / #domain AND #Instagram page ...
# 30520  #NFT &amp; #Polkadot or #NFTCommunity \nand @P...
# 30521                                        What is nft
# 30522  @MattTea5 what's an nft\nᵃᵐ ⁱ ᵈᵒⁱⁿᵍ ⁱᵗ ʳⁱᵍʰᵗ ?...
# 30523  DO WE #catecoin OR #Dogecoin ?\n#cryptocurrenc...
#
#                                            cleaned_tweet
# 0                           our new favorite hash tag is
# 1                watch pump video lets re sell this girl
# 2      hope hand painted oil painting splash ink art ...
# 3      you want us to check your drop them here follo...
# 4      these are the first pieces minted in my vast c...
# ...                                                  ...
# 30519  and page with followers in the space marlon br...
# 30520                                             or and
# 30521                                        what is nft
# 30522                                      what s an nft
# 30523                                           do we or
#
# [30512 rows x 5 columns]

# %%
# split created_at into date and time columns
#https://intellipaat.com/community/13909/python-how-can-i-split-a-column-with-both-date-and-time-e-g-2019-07-02-00-12-32-utc-into-two-separate-columns
df['created_at'] = pd.to_datetime(df['created_at'])
df['date'] = df['created_at'].dt.date
df['time'] = df['created_at'].dt.time
df
# Out:
#        tweet_index          created_at  maxtopic  \
# 0            20961 2021-05-26 06:34:56         0
# 1             6759 2021-05-30 06:36:50         0
# 2             5260 2021-05-30 16:29:15         0
# 3            16594 2021-05-27 08:42:19         0
# 4            16601 2021-05-27 08:37:47         0
# ...            ...                 ...       ...
# 30519        26959 2021-05-25 00:49:49       100
# 30520        10319 2021-05-29 01:20:58       100
# 30521        16463 2021-05-27 09:34:19       100
# 30522        17895 2021-05-26 20:52:52       100
# 30523        16290 2021-05-27 10:52:49       100
#
#                                                   corpus  \
# 0      Our new favorite hash tag is #trapdontshill\n\...
# 1      @dikparkes Watch PUMP #NFT video!🤑\nLets re-se...
# 2      @pranksyNFT @BoredApeYC @MeebitsDAO Hope hand ...
# 3      You want us to check your #NFTs. Drop them her...
# 4      @paris_museum These are the first 4 pieces min...
# ...                                                  ...
# 30519  #Crypto #wallet / #domain AND #Instagram page ...
# 30520  #NFT &amp; #Polkadot or #NFTCommunity \nand @P...
# 30521                                        What is nft
# 30522  @MattTea5 what's an nft\nᵃᵐ ⁱ ᵈᵒⁱⁿᵍ ⁱᵗ ʳⁱᵍʰᵗ ?...
# 30523  DO WE #catecoin OR #Dogecoin ?\n#cryptocurrenc...
#
#                                            cleaned_tweet        date      time
# 0                           our new favorite hash tag is  2021-05-26  06:34:56
# 1                watch pump video lets re sell this girl  2021-05-30  06:36:50
# 2      hope hand painted oil painting splash ink art ...  2021-05-30  16:29:15
# 3      you want us to check your drop them here follo...  2021-05-27  08:42:19
# 4      these are the first pieces minted in my vast c...  2021-05-27  08:37:47
# ...                                                  ...         ...       ...
# 30519  and page with followers in the space marlon br...  2021-05-25  00:49:49
# 30520                                             or and  2021-05-29  01:20:58
# 30521                                        what is nft  2021-05-27  09:34:19
# 30522                                      what s an nft  2021-05-26  20:52:52
# 30523                                           do we or  2021-05-27  10:52:49
#
# [30512 rows x 7 columns]

# %%
topic = 4

# %%
df = df[df["maxtopic"] == topic]
df
# Out:
#        tweet_index          created_at  maxtopic  \
# 7404         21493 2021-05-26 03:08:21         4
# 7405         11565 2021-05-28 16:27:24         4
# 7406         27952 2021-05-24 17:24:29         4
# 7407         21397 2021-05-26 03:49:04         4
# 7408         21488 2021-05-26 03:11:09         4
# ...            ...                 ...       ...
# 11689         1967 2021-05-31 12:05:29         4
# 11690         8885 2021-05-29 14:04:12         4
# 11691         1865 2021-05-31 12:38:41         4
# 11692         1847 2021-05-31 12:42:45         4
# 11693         1988 2021-05-31 12:01:05         4
#
#                                                   corpus  \
# 7404   @Smart_NFT_News @hodooicom Such a perfect pick...
# 7405   “I am participating in @https://twitter.com/nf...
# 7406   @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407   I am participating in @nftgateio airdrop\n\n@R...
# 7408   “I am participating in @https://twitter.com/nf...
# ...                                                  ...
# 11689  @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690  I am participating in @https://twitter.com/nft...
# 11691  @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692  Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693  @DCryptoQueen @llxxppgg Incredible project \n@...
#
#                                            cleaned_tweet        date      time
# 7404   such a perfect pick for your marketing gold st...  2021-05-26  03:08:21
# 7405   i am participating in twitter com nftgateio ai...  2021-05-28  16:27:24
# 7406   road to nowhere loop animation with loop sound...  2021-05-24  17:24:29
# 7407                       i am participating in airdrop  2021-05-26  03:49:04
# 7408   i am participating in twitter com nftgateio ai...  2021-05-26  03:11:09
# ...                                                  ...         ...       ...
# 11689                                          thank you  2021-05-31  12:05:29
# 11690  i am participating in twitter com nftgateio ai...  2021-05-29  14:04:12
# 11691                  nice airdrop join airdrop with me  2021-05-31  12:38:41
# 11692                                follow this project  2021-05-31  12:42:45
# 11693                        incredible project w ra wam  2021-05-31  12:01:05
#
# [4290 rows x 7 columns]

# %%
analyzer = SentimentIntensityAnalyzer()
for tweet in df["cleaned_tweet"]:
    vs = analyzer.polarity_scores(tweet)
    print("{:-<65} {}".format(tweet, str(vs)))
# Out:
# such a perfect pick for your marketing gold star promotion is a great partner for your project {'neg': 0.0, 'neu': 0.658, 'pos': 0.342, 'compound': 0.8316}
# i am participating in twitter com nftgateio airdrop and tag friends airdrop with hashtags {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.4767}
# road to nowhere loop animation with loop sound price tez only on link {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in airdrop------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# lets bring to waves ducks collections why because we need a woman in the ducks collections nah she is also cryptolovers and nft lovers waves {'neg': 0.05, 'neu': 0.827, 'pos': 0.122, 'compound': 0.4588}
# i am participating in nftgateio airdrop-------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in airdrop------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in the cryptoultraman nft airdrop round very good project {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4927}
# gas ias low this is the best time to invest in nft--------------- {'neg': 0.129, 'neu': 0.613, 'pos': 0.258, 'compound': 0.4767}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# their nft exchange is what i m excited for----------------------- {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.34}
# i am participating in the cryptoultraman nft airdrop round------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# join the crts airdrop-------------------------------------------- {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.296}
# i am participating in the cryptoultraman nft airdrop round------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# nice project reset----------------------------------------------- {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.4215}
# gas ias low this is the best time to invest in nft--------------- {'neg': 0.129, 'neu': 0.613, 'pos': 0.258, 'compound': 0.4767}
# help me win this awesome competition from------------------------ {'neg': 0.0, 'neu': 0.26, 'pos': 0.74, 'compound': 0.9076}
# gas ias low this is the best time to invest in nft--------------- {'neg': 0.129, 'neu': 0.613, 'pos': 0.258, 'compound': 0.4767}
# a good project i have joined airdrop----------------------------- {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}
# superrare rt my latest over on this has been hugely exciting combining my traditional painting with d animation winning bidder will receive physical artwork x cm # {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.7841}
# i am participating in the cryptoultraman nft airdrop round------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in the cryptoultraman nft airdrop round and mark {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in the cryptoultraman nft airdrop round------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in airdrop------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in the cryptoultraman nft airdrop round------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# really very good project i am participating in airdrop----------- {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.5379}
# i am participating in the cryptoultraman nft airdrop round and mark {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in airdrop------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# read a like you never have before with which has just released s as a digital only book complete with optional exclusive content {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.4588}
# i am participating in twitter com nftgateio airdrop and tag friends airdrop with hashtags {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.4767}
# the game changer for adoption is here on introducing whitelisting process is now live until pm utc on wed may wise details here {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4767}
# i am participating in the cryptoultraman nft airdrop round and mark {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in airdrop------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# this physical nft will exclusively be available to people who own or more gumbos burn gumbos nft burn or more gumbos physical nft {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in airdrop------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# interested in this project--------------------------------------- {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in the cryptoultraman nft airdrop round------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# very good project------------------------------------------------ {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.4927}
# ...
# available piece on reflecting on the last year of lockdowns here in the uk and the rest of the world collab with {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# my acrylic painting as nft series of----------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# good project everybody should join this great project thanks for giving us this amazing airdropsmiling face with hearts reset {'neg': 0.0, 'neu': 0.339, 'pos': 0.661, 'compound': 0.9732}
# first drop the broken mind collection fleeting nft available at-- {'neg': 0.394, 'neu': 0.606, 'pos': 0.0, 'compound': -0.6369}
# i m joining hsc mainnet to win nft airdrops thanks to------------ {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'compound': 0.7717}
# can you really apply a filter and edit a late artist s work and call it an original christie s auctioned some previously seen andy warhol pieces but applied sharpness filters and edited the ratio leading to a mixed reaction {'neg': 0.0, 'neu': 0.959, 'pos': 0.041, 'compound': 0.1655}
# unifty is a leading platform with the best features available for nfts artists go check it out and don t miss the train nif eth {'neg': 0.056, 'neu': 0.799, 'pos': 0.146, 'compound': 0.5574}
# this company includes the best quality to become a leading in the market we are witnessing a huge increase the company is gaining momentum and shows great results a great opportunity to become an investor of an ambitious team {'neg': 0.0, 'neu': 0.547, 'pos': 0.453, 'compound': 0.9769}
# dedhorse airdrop sent to the mystery poet musing on that familiar feeling of parachuting into helicopter blades in other news the whole collection has been official listed for sale get em here {'neg': 0.0, 'neu': 0.954, 'pos': 0.046, 'compound': 0.128}
# and some i ve already mentioned but all the love to the polakdinner on opensea thank you for believing in the eggbois early on so much more to come {'neg': 0.0, 'neu': 0.749, 'pos': 0.251, 'compound': 0.8765}
# nice update today for valereum blockchain launch of vlrm secured listed securities nft feeling bullish for these disrupters {'neg': 0.0, 'neu': 0.603, 'pos': 0.397, 'compound': 0.802}
# am participating in twitter com nftgateio airdrop---------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in the cryptoultraman nft airdrop round------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# falling from hue collectible via--------------------------------- {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.1531}
# this project is very good i love the project i believe this project will boom rocket smiling face with open mouthcollision symbol in future {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.8923}
# thurik anantia collection via------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# charlie bit my finger is leaving youtube after nft sale---------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in guys check this amazing project out it s going to be massive and you don t wanna miss out on this {'neg': 0.055, 'neu': 0.79, 'pos': 0.155, 'compound': 0.5994}
# is making so much hype they even partnered with their on got sold out in seconds they will allow you to challenge anyone anywhere in sports to earn moov token and collectible {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.296}
# look what i found past and future collectible via---------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# good project i am participating in twitter com nftgateio airdrop- {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4404}
# excited to be here at learning about s and with the adult content nft marketplace {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.34}
# when i share another primed with a lower mcap despite the primed chart and midterm potential much higher i rather share with my sub k follower alter ego {'neg': 0.07, 'neu': 0.791, 'pos': 0.139, 'compound': 0.296}
# sell top farts as an nft----------------------------------------- {'neg': 0.0, 'neu': 0.735, 'pos': 0.265, 'compound': 0.2023}
# thank you-------------------------------------------------------- {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'compound': 0.3612}
# great project---------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# crazy a blockchain based gaming and live casino platform they also build a nft gambling platform strong investors very tiny market cap at tge {'neg': 0.087, 'neu': 0.794, 'pos': 0.119, 'compound': 0.2263}
# my new nft the vision is available on---------------------------- {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.25}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# i am participating in the cryptoultraman nft airdrop round------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# that s amazing man you re always so active and supportive in the nft community and it s very nice to see that two amazing collectors have noticed your work good luck and keep it up {'neg': 0.0, 'neu': 0.563, 'pos': 0.437, 'compound': 0.9703}
# check out this for sale on mintable pick up musk a lisa before its swooped up just for {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# another nft thing------------------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in twitter com nftgateio---------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i wonder if my will endure the test of time on board a in carrying it and forever into an amazing journey a never ending quest for new i believe it will {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.5859}
# check out this for sale on mintable pick up secret behind pyramides before its swooped up this art is trying to show may be there is secret behind the egypt pyramids which we can understand when we make huge progress in digital world years {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.6249}
# i m joining hsc mainnet to win nft airdrops thanks to------------ {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'compound': 0.7717}
# my pleasure i m so happy to finish my collection so honor to collect your early nft work {'neg': 0.0, 'neu': 0.544, 'pos': 0.456, 'compound': 0.9268}
# i am participating in-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in airdrop------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# get your tank works on criminally low entry price at tez--------- {'neg': 0.174, 'neu': 0.826, 'pos': 0.0, 'compound': -0.2732}
# china s first nft asset trading platform a new coin let s witness the birth of x times telegram twitter contract address x f f a ed fb d d b d ca follow and retweet twitter and leave bsc address to receive coin airdrop {'neg': 0.026, 'neu': 0.921, 'pos': 0.054, 'compound': 0.3182}
# here s my work for event traumaspective viii zapping through for tez cos of bots event page {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# my mother passed away from covid late last year her importance made me realise how women are seriously being disrespected and taken for granted tez ed of {'neg': 0.146, 'neu': 0.714, 'pos': 0.14, 'compound': -0.0516}
# girls just want to have fun weekend nftart lovely sexy happy----- {'neg': 0.0, 'neu': 0.279, 'pos': 0.721, 'compound': 0.9382}
# i am participating in the cryptoultraman nft airdrop round and mark {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i m joining hsc mainnet to win nft airdrops thanks to------------ {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'compound': 0.7717}
# summer vibez----------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# check out this for sale on mintable pick up brutalist before its swooped up {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i claimed some gala and nft s from my gala node this morning since gas prices were low and it s hours and still pending wow i can t wait to never use eth again {'neg': 0.054, 'neu': 0.848, 'pos': 0.098, 'compound': 0.4019}
# you are the hero------------------------------------------------- {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'compound': 0.5574}
# i am participating guys check this amazing project out it s going to be massive and you don t wanna miss out on this {'neg': 0.057, 'neu': 0.783, 'pos': 0.16, 'compound': 0.5994}
# freshly minted cardanoape d x------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# very good project i am participating in twitter com nftgateio airdrop {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.4927}
# drop of hope----------------------------------------------------- {'neg': 0.35, 'neu': 0.167, 'pos': 0.483, 'compound': 0.2023}
# new world order we are indeed living historic moments the kind of occasion where the crisis calls in to question all certainties and minds are more open to change x px reserve price eth {'neg': 0.108, 'neu': 0.842, 'pos': 0.05, 'compound': -0.4939}
# i am participating in the cryptoultraman nft airdrop round and mark {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# remember to subscribe to my newsletter each subscriber gets to show one nft in the upcoming editions {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# new drop ainftcreator collection--------------------------------- {'neg': 0.412, 'neu': 0.588, 'pos': 0.0, 'compound': -0.2732}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i m joining hsc mainnet to win nft airdrops thanks to------------ {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'compound': 0.7717}
# look at this big news apparently leads to a gme eth hash crypto dip {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# awesome project hope the biggest one someday and thanks for teamwork team because of you this project can be goes to moon once mire congratulation good luck so much {'neg': 0.0, 'neu': 0.539, 'pos': 0.461, 'compound': 0.9623}
# they should just go acquire all the nft gaming projects out there {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# the future of nft the team behind doggy is probably one of the best out there also the progress it have done in such a short notice make it pop up above any other coin doggy {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.7906}
# i m joining hsc mainnet to win nft airdrops thanks to------------ {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'compound': 0.7717}
# any news on this would be amazing especially taking rarity into account for the amount of yield you get foo ftm yield nft {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.5859}
# turkish mafia and street gangs check out this for sale on mintable pick up hamdi before its swooped up {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# make an---------------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# right when no one can sell back the they bought few months ago gme launches the items page just facinating {'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'compound': -0.296}
# i am participating in airdrop------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# nice project reset----------------------------------------------- {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.4215}
# reset good airdrop----------------------------------------------- {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
# icelandic aura would swim in those enormous waves so why you wouldn t let s swim people {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# thank you very much my friend for giving me this incredible i am very happy to receive this beautiful art made by the artist antonio carlos {'neg': 0.0, 'neu': 0.553, 'pos': 0.447, 'compound': 0.9515}
# nice they should do the share certificates as nft s-------------- {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.6124}
# at this point i believe it is clear that nfts represent an improvement in asset ownership and will only continue to grow over time i m onboard the nft stack thesis projects that offer utility for nfts allow nfts to do more for you and you to do more with nfts {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.8402}
# it would be an nft restaurant the dishes would be absurdly expensive and all you get is an image of the food you ordered {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# the mind is god is available on now link in bio edition price---- {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.2732}
# songs videos and digital artwork are being auctioned for millions of dollars digital artist sold an nft for kes billion but first things first what are n f ts find out more in this article {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# nice project this is amazing good work nft x--------------------- {'neg': 0.0, 'neu': 0.387, 'pos': 0.613, 'compound': 0.8591}
# check out this awesome nft--------------------------------------- {'neg': 0.0, 'neu': 0.451, 'pos': 0.549, 'compound': 0.7073}
# something something nft poetry----------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i m joining hsc mainnet to win nft airdrops thanks to------------ {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'compound': 0.7717}
# i am participating in twitter com nftgateio airdrop-------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# i am participating in the cryptoultraman nft airdrop round and mark {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# the mind is god is available on now link in bio edition price---- {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.2732}
# i love r planet join the discord member giveaway----------------- {'neg': 0.179, 'neu': 0.397, 'pos': 0.424, 'compound': 0.5719}
# i love r planet join the discord member giveaway----------------- {'neg': 0.179, 'neu': 0.397, 'pos': 0.424, 'compound': 0.5719}
# good project i am participating in the cryptoultraman nft airdrop round and mark {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.4404}
# lifeguard of daytona beach striking a pose while watching everyone at the beach {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# good project hopefully in the future it can be even more successful for the team {'neg': 0.0, 'neu': 0.553, 'pos': 0.447, 'compound': 0.8655}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-3ea32b2029fc> in <module>
#       1 analyzer = SentimentIntensityAnalyzer()
#       2 for tweet in df["cleaned_tweet"]:
# ----> 3     vs = analyzer.polarity_scores(tweet)
#       4     print("{:-<65} {}".format(tweet, str(vs)))
#
# ~/Documents/ISM/Research/dev/env/lib/python3.8/site-packages/vaderSentiment/vaderSentiment.py in polarity_scores(self, text)
#     239         text_no_emoji = ""
#     240         prev_space = True
# --> 241         for chr in text:
#     242             if chr in self.emojis:
#     243                 # get the textual description
#
# TypeError: 'float' object is not iterable

# %%
df["cleaned_tweet"]
# Out:
# 7404     such a perfect pick for your marketing gold st...
# 7405     i am participating in twitter com nftgateio ai...
# 7406     road to nowhere loop animation with loop sound...
# 7407                         i am participating in airdrop
# 7408     i am participating in twitter com nftgateio ai...
#                                ...
# 11689                                            thank you
# 11690    i am participating in twitter com nftgateio ai...
# 11691                    nice airdrop join airdrop with me
# 11692                                  follow this project
# 11693                          incredible project w ra wam
# Name: cleaned_tweet, Length: 4290, dtype: object

# %%
df["corpus"]
# Out:
# 7404     @Smart_NFT_News @hodooicom Such a perfect pick...
# 7405     “I am participating in @https://twitter.com/nf...
# 7406     @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407     I am participating in @nftgateio airdrop\n\n@R...
# 7408     “I am participating in @https://twitter.com/nf...
#                                ...
# 11689    @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690    I am participating in @https://twitter.com/nft...
# 11691    @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692    Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693    @DCryptoQueen @llxxppgg Incredible project \n@...
# Name: corpus, Length: 4290, dtype: object

# %%
# check whether there are any null values in cleaned_tweet
df[df["cleaned_tweet"].isnull()]
# Out:
#       tweet_index          created_at  maxtopic  \
# 8240        22072 2021-05-25 22:30:14         4
#
#                                                  corpus cleaned_tweet  \
# 8240  @Bitboy_Crypto @TribeOneDeFi a unique platform...           NaN
#
#             date      time
# 8240  2021-05-25  22:30:14

# %%
# remove all NaN values from cleaned_tweet
df = df.drop(df[df["cleaned_tweet"].isnull()].index)
df
# Out:
#        tweet_index          created_at  maxtopic  \
# 7404         21493 2021-05-26 03:08:21         4
# 7405         11565 2021-05-28 16:27:24         4
# 7406         27952 2021-05-24 17:24:29         4
# 7407         21397 2021-05-26 03:49:04         4
# 7408         21488 2021-05-26 03:11:09         4
# ...            ...                 ...       ...
# 11689         1967 2021-05-31 12:05:29         4
# 11690         8885 2021-05-29 14:04:12         4
# 11691         1865 2021-05-31 12:38:41         4
# 11692         1847 2021-05-31 12:42:45         4
# 11693         1988 2021-05-31 12:01:05         4
#
#                                                   corpus  \
# 7404   @Smart_NFT_News @hodooicom Such a perfect pick...
# 7405   “I am participating in @https://twitter.com/nf...
# 7406   @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407   I am participating in @nftgateio airdrop\n\n@R...
# 7408   “I am participating in @https://twitter.com/nf...
# ...                                                  ...
# 11689  @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690  I am participating in @https://twitter.com/nft...
# 11691  @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692  Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693  @DCryptoQueen @llxxppgg Incredible project \n@...
#
#                                            cleaned_tweet        date      time
# 7404   such a perfect pick for your marketing gold st...  2021-05-26  03:08:21
# 7405   i am participating in twitter com nftgateio ai...  2021-05-28  16:27:24
# 7406   road to nowhere loop animation with loop sound...  2021-05-24  17:24:29
# 7407                       i am participating in airdrop  2021-05-26  03:49:04
# 7408   i am participating in twitter com nftgateio ai...  2021-05-26  03:11:09
# ...                                                  ...         ...       ...
# 11689                                          thank you  2021-05-31  12:05:29
# 11690  i am participating in twitter com nftgateio ai...  2021-05-29  14:04:12
# 11691                  nice airdrop join airdrop with me  2021-05-31  12:38:41
# 11692                                follow this project  2021-05-31  12:42:45
# 11693                        incredible project w ra wam  2021-05-31  12:01:05
#
# [4289 rows x 7 columns]

# %%
#https://github.com/sidneykung/twitter_hate_speech_detection/blob/master/preprocessing/VADER_sentiment.ipynb
pol = lambda x: analyzer.polarity_scores(x)
df['Polarity'] = df["cleaned_tweet"].apply(pol)
df
# Out:
#        tweet_index          created_at  maxtopic  \
# 7404         21493 2021-05-26 03:08:21         4
# 7405         11565 2021-05-28 16:27:24         4
# 7406         27952 2021-05-24 17:24:29         4
# 7407         21397 2021-05-26 03:49:04         4
# 7406   @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407   I am participating in @nftgateio airdrop\n\n@R...
# 7408   “I am participating in @https://twitter.com/nf...
# ...                                                  ...
# 11689  @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690  I am participating in @https://twitter.com/nft...
# 11691  @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692  Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693  @DCryptoQueen @llxxppgg Incredible project \n@...
#
#                                            cleaned_tweet        date  \
# 7404   such a perfect pick for your marketing gold st...  2021-05-26
# 7405   i am participating in twitter com nftgateio ai...  2021-05-28
# 7406   road to nowhere loop animation with loop sound...  2021-05-24
# 7407                       i am participating in airdrop  2021-05-26
# 7408   i am participating in twitter com nftgateio ai...  2021-05-26
# ...                                                  ...         ...
# 11689                                          thank you  2021-05-31
# 11690  i am participating in twitter com nftgateio ai...  2021-05-29
# 11691                  nice airdrop join airdrop with me  2021-05-31
# 11692                                follow this project  2021-05-31
# 11693                        incredible project w ra wam  2021-05-31
#
#            time  neg    neu    pos  compound
# 7404   03:08:21  0.0  0.658  0.342    0.8316
# 7405   16:27:24  0.0  0.807  0.193    0.4767
# 7406   17:24:29  0.0  1.000  0.000    0.0000
# 7407   03:49:04  0.0  1.000  0.000    0.0000
# 7408   03:11:09  0.0  1.000  0.000    0.0000
# ...         ...  ...    ...    ...       ...
# 11689  12:05:29  0.0  0.286  0.714    0.3612
# 11690  14:04:12  0.0  0.763  0.237    0.4215
# 11691  12:38:41  0.0  0.444  0.556    0.6124
# 11692  12:42:45  0.0  1.000  0.000    0.0000
# 11693  12:01:05  0.0  1.000  0.000    0.0000
#
# [4289 rows x 11 columns]

# %%
plt.plot(df.index, df['compound'].sort_values())
plt.title('Topic {}: Sentiment Analysis using Vader'.format(topic))
plt.ylabel('Polarity')
plt.xlabel('Tweets')
# Out:
# Text(0.5, 0, 'Tweets')

# %%
def calc_polarity(x, bound):
    if x < -0.05:
        return -1
    elif x > 0.05:
        return 1
    else:
        return 0

round_pol = lambda x: calc_polarity(x, 0.05)

# %%
df['compound']
# Out:
# 7404     0.8316
# 7405     0.4767
# 7406     0.0000
# 7407     0.0000
# 7408     0.0000
#           ...
# 11689    0.3612
# 11690    0.4215
# 11691    0.6124
# 11692    0.0000
# 11693    0.0000
# Name: compound, Length: 4289, dtype: float64

# %%
df['Polarity'] = df['compound'].apply(round_pol)
df
# Out:
#        tweet_index          created_at  maxtopic  \
# 7404         21493 2021-05-26 03:08:21         4
# 7405         11565 2021-05-28 16:27:24         4
# 7406         27952 2021-05-24 17:24:29         4
# 7407         21397 2021-05-26 03:49:04         4
# 7408         21488 2021-05-26 03:11:09         4
# ...            ...                 ...       ...
# 11689         1967 2021-05-31 12:05:29         4
# 11690         8885 2021-05-29 14:04:12         4
# 11691         1865 2021-05-31 12:38:41         4
# 11692         1847 2021-05-31 12:42:45         4
# 11693         1988 2021-05-31 12:01:05         4
#
#                                                   corpus  \
# 7404   @Smart_NFT_News @hodooicom Such a perfect pick...
# 7405   “I am participating in @https://twitter.com/nf...
# 7406   @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407   I am participating in @nftgateio airdrop\n\n@R...
# 7408   “I am participating in @https://twitter.com/nf...
# ...                                                  ...
# 11689  @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690  I am participating in @https://twitter.com/nft...
# 11691  @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692  Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693  @DCryptoQueen @llxxppgg Incredible project \n@...
#
#                                            cleaned_tweet        date  \
# 7404   such a perfect pick for your marketing gold st...  2021-05-26
# 7405   i am participating in twitter com nftgateio ai...  2021-05-28
# 7406   road to nowhere loop animation with loop sound...  2021-05-24
# 7407                       i am participating in airdrop  2021-05-26
# 7408   i am participating in twitter com nftgateio ai...  2021-05-26
# ...                                                  ...         ...
# 11689                                          thank you  2021-05-31
# 11690  i am participating in twitter com nftgateio ai...  2021-05-29
# 11691                  nice airdrop join airdrop with me  2021-05-31
# 11692                                follow this project  2021-05-31
# 11693                        incredible project w ra wam  2021-05-31
#
#            time  neg    neu    pos  compound  Polarity
# 7404   03:08:21  0.0  0.658  0.342    0.8316         1
# 7405   16:27:24  0.0  0.807  0.193    0.4767         1
# 7406   17:24:29  0.0  1.000  0.000    0.0000         0
# 7407   03:49:04  0.0  1.000  0.000    0.0000         0
# 7408   03:11:09  0.0  1.000  0.000    0.0000         0
# ...         ...  ...    ...    ...       ...       ...
# 11689  12:05:29  0.0  0.286  0.714    0.3612         1
# 11690  14:04:12  0.0  0.763  0.237    0.4215         1
# 11691  12:38:41  0.0  0.444  0.556    0.6124         1
# 11692  12:42:45  0.0  1.000  0.000    0.0000         0
# 11693  12:01:05  0.0  1.000  0.000    0.0000         0
#
# [4289 rows x 12 columns]

# %% [markdown]
# # Plot Results

# %%
plt.plot(df.index, df['Polarity'].sort_values())
plt.title('Topic {}: Sentiment Analysis using Vader'.format(topic))
plt.ylabel('Polarity')
plt.xlabel('Tweets')
# Out:
# Text(0.5, 0, 'Tweets')

# %%
sentiments = df.groupby('Polarity').count()
sentiments
# Out:
#           tweet_index  created_at  maxtopic  corpus  cleaned_tweet  date  \
# Polarity
# -1                 98          98        98      98             98    98
#  0               1811        1811      1811    1811           1811  1811
#  1               2380        2380      2380    2380           2380  2380
#
#           time   neg   neu   pos  compound
# Polarity
# -1          98    98    98    98        98
#  0        1811  1811  1811  1811      1811
#  1        2380  2380  2380  2380      2380

# %%
plt.bar(sentiments.index, sentiments["compound"])
plt.title('Topic {}: Sentiment'.format(topic))
plt.xlabel('Polarity')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#group tweets by date
dates = df.groupby('date').count()
dates
# Out:
#             tweet_index  created_at  maxtopic  corpus  cleaned_tweet  time  \
# date
# 2021-05-23           41          41        41      41             41    41
# 2021-05-24          233         233       233     233            233   233
# 2021-05-25          654         654       654     654            654   654
# 2021-05-26          687         687       687     687            687   687
# 2021-05-27          269         269       269     269            269   269
# 2021-05-28          580         580       580     580            580   580
# 2021-05-29          463         463       463     463            463   463
# 2021-05-30          514         514       514     514            514   514
# 2021-05-31          848         848       848     848            848   848
#
#             neg  neu  pos  compound  Polarity
# date
# 2021-05-23   41   41   41        41        41
# 2021-05-24  233  233  233       233       233
# 2021-05-25  654  654  654       654       654
# 2021-05-26  687  687  687       687       687
# 2021-05-27  269  269  269       269       269
# 2021-05-28  580  580  580       580       580
# 2021-05-29  463  463  463       463       463
# 2021-05-30  514  514  514       514       514
# 2021-05-31  848  848  848       848       848

# %%
dates.index
# Out:
# Index([2021-05-23, 2021-05-24, 2021-05-25, 2021-05-26, 2021-05-27, 2021-05-28,
#        2021-05-29, 2021-05-30, 2021-05-31],
#       dtype='object', name='date')

# %%
dates['day'] = ''
for i in range(0, len(dates.index)):
    dates['day'][i] = dates.index[i].day
dates
# Out:
# <ipython-input-24-3887fc99946e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
#             tweet_index  created_at  maxtopic  corpus  cleaned_tweet  time  \
# date
# 2021-05-23           41          41        41      41             41    41
# 2021-05-24          233         233       233     233            233   233
# 2021-05-25          654         654       654     654            654   654
# 2021-05-26          687         687       687     687            687   687
# 2021-05-27          269         269       269     269            269   269
# 2021-05-28          580         580       580     580            580   580
# 2021-05-29          463         463       463     463            463   463
# 2021-05-30          514         514       514     514            514   514
# 2021-05-31          848         848       848     848            848   848
#
#             neg  neu  pos  compound  Polarity day
# date
# 2021-05-23   41   41   41        41        41  23
# 2021-05-24  233  233  233       233       233  24
# 2021-05-25  654  654  654       654       654  25
# 2021-05-26  687  687  687       687       687  26
# 2021-05-27  269  269  269       269       269  27
# 2021-05-28  580  580  580       580       580  28
# 2021-05-29  463  463  463       463       463  29
# 2021-05-30  514  514  514       514       514  30
# 2021-05-31  848  848  848       848       848  31

# %%
#plot tweet frequency over time
plt.plot(dates['day'], dates['cleaned_tweet'])
plt.title('Topic4 Tweet Frequency')
plt.xlabel('Day of May 2021')
plt.ylabel('Count of Topic4 Tweets')
# Out:
# Text(0, 0.5, 'Count of Topic4 Tweets')

# %%
df
# Out:
#        tweet_index          created_at  maxtopic  \
# 7404         21493 2021-05-26 03:08:21         4
# 7405         11565 2021-05-28 16:27:24         4
# 7406         27952 2021-05-24 17:24:29         4
# 7407         21397 2021-05-26 03:49:04         4
# 7408         21488 2021-05-26 03:11:09         4
# ...            ...                 ...       ...
# 11689         1967 2021-05-31 12:05:29         4
# 11690         8885 2021-05-29 14:04:12         4
# 11691         1865 2021-05-31 12:38:41         4
# 11692         1847 2021-05-31 12:42:45         4
# 11693         1988 2021-05-31 12:01:05         4
#
#                                                   corpus  \
# 7404   @Smart_NFT_News @hodooicom Such a perfect pick...
# 7405   “I am participating in @https://twitter.com/nf...
# 7406   @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407   I am participating in @nftgateio airdrop\n\n@R...
# 7408   “I am participating in @https://twitter.com/nf...
# ...                                                  ...
# 11689  @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690  I am participating in @https://twitter.com/nft...
# 11691  @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692  Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693  @DCryptoQueen @llxxppgg Incredible project \n@...
#
#                                            cleaned_tweet        date  \
# 7404   such a perfect pick for your marketing gold st...  2021-05-26
# 7405   i am participating in twitter com nftgateio ai...  2021-05-28
# 7406   road to nowhere loop animation with loop sound...  2021-05-24
# 7407                       i am participating in airdrop  2021-05-26
# 7408   i am participating in twitter com nftgateio ai...  2021-05-26
# ...                                                  ...         ...
# 11689                                          thank you  2021-05-31
# 11690  i am participating in twitter com nftgateio ai...  2021-05-29
# 11691                  nice airdrop join airdrop with me  2021-05-31
# 11692                                follow this project  2021-05-31
# 11693                        incredible project w ra wam  2021-05-31
#
#            time  neg    neu    pos  compound  Polarity
# 7404   03:08:21  0.0  0.658  0.342    0.8316         1
# 7405   16:27:24  0.0  0.807  0.193    0.4767         1
# 7406   17:24:29  0.0  1.000  0.000    0.0000         0
# 7407   03:49:04  0.0  1.000  0.000    0.0000         0
# 7408   03:11:09  0.0  1.000  0.000    0.0000         0
# ...         ...  ...    ...    ...       ...       ...
# 11689  12:05:29  0.0  0.286  0.714    0.3612         1
# 11690  14:04:12  0.0  0.763  0.237    0.4215         1
# 11691  12:38:41  0.0  0.444  0.556    0.6124         1
# 11692  12:42:45  0.0  1.000  0.000    0.0000         0
# 11693  12:01:05  0.0  1.000  0.000    0.0000         0
#
# [4289 rows x 12 columns]

# %%
df['date'].iloc[4287] == df['date'].iloc[4288]
# Out:
# True

# %%
df['compound'].iloc[0]
# Out:
# 0.8316

# %%
len(df.index)
# Out:
# 4289

# %%
sumsentiment = 0
count = 0
for i in range(len(df.index)):
    if df['date'].iloc[i] == df['date'].iloc[0]:
        sumsentiment += df['compound'].iloc[i]
        count += 1
avg = sumsentiment / count
# print(df['date'].iloc[0])
avg
# Out:
# 0.34505123726346526

# %%
#calculate average sentiment per day
#https://stackoverflow.com/questions/67899247/compute-column-average-based-on-conditions-pandas
df_avg = df.groupby(['date'], as_index=False)['compound'].mean()
df_avg
# Out:
#          date  compound
# 0  2021-05-23  0.343083
# 1  2021-05-24  0.354258
# 2  2021-05-25  0.388533
# 3  2021-05-26  0.345051
# 4  2021-05-27  0.369923
# 5  2021-05-28  0.279810
# 6  2021-05-29  0.253230
# 7  2021-05-30  0.261841
# 8  2021-05-31  0.299849

# %%
#add day from date as separate column
df_avg['day'] = ''
for i in range(0, len(df_avg.index)):
    df_avg['day'][i] = df_avg['date'][i].day

#plot average sentiment over time
plt.plot(df_avg['day'], df_avg['compound'])
plt.title('Topic4 Sentiment Over Time')
plt.ylabel('Average Polarity')
plt.xlabel('Day of May 2021')
# Out:
# <ipython-input-32-8dbd596dc9c3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# Text(0.5, 0, 'Day of May 2021')
