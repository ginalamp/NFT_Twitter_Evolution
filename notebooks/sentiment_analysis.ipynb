# %% [markdown]
# # Sentiment Analysis on Specific Topics
#
# Sentiment analysis per topic.
# Automated and step-by step version.

# %%
# dependencies - install first time using this notebook
# !pip3 install vaderSentiment
# !pip3 install --upgrade pip
# !pip3 install xlrd
# !pip3 install openpyxl

import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# %% [markdown]
# # Sentiment Automation
#
# Run the below block if you want everything to be done automatically all at once.
# It will output the graphs into `dataout/sentiment/*`
#
# If you want a step-by-step understanding, then see the code below this block.

# %%
def df_setup():
    # read in data produced by topic_modelling.ipynb
    df = pd.read_csv('../datain/sentiment/grouped-by-topic_with_date.csv')
    df = df[['Unnamed: 0', 'created_at', 'maxtopic', 'corpus', "cleaned_tweet"]].copy()
    df = df.rename({'Unnamed: 0': 'tweet_index'}, axis=1)
    
    # remove any null created_at values from dataframe
    df = df.drop(df[df['created_at'].isnull()].index)
    # ensure that all values in created_at has 2021 (and not random strings)
    df = df[df['created_at'].str.contains("2021")]
    
    # split created_at into date and time columns
    #https://intellipaat.com/community/13909/python-how-can-i-split-a-column-with-both-date-and-time-e-g-2019-07-02-00-12-32-utc-into-two-separate-columns
    df['created_at'] = pd.to_datetime(df['created_at'])
    df['date'] = df['created_at'].dt.date
    df['time'] = df['created_at'].dt.time
    
    return df
    
def sentiment_analysis_per_topic(df, topic):
    # filter df to only have data for the given topic
    df = df[df["maxtopic"] == topic]
    
    # get polarity scores per tweet
    analyzer = SentimentIntensityAnalyzer()
    for tweet in df["corpus"]:
        vs = analyzer.polarity_scores(tweet)
        
    #https://github.com/sidneykung/twitter_hate_speech_detection/blob/master/preprocessing/VADER_sentiment.ipynb
    pol = lambda x: analyzer.polarity_scores(x)
    df['Polarity'] = df['corpus'].apply(pol)
    
    df = pd.concat([df.drop(['Polarity'], axis=1), df['Polarity'].apply(pd.Series)], axis=1)
    # plot first sentiment
    plot_sentiment(df, topic)
    
    # plot 2nd sentiment
    round_pol = lambda x: calc_pol(x, 0.05)
    df['Polarity'] = df['compound'].apply(round_pol)
    plot_sentiment2(df, topic)
    
    # plot 3rd sentiment
    sentiments = df.groupby('Polarity').count()
    plot_sentiment3(sentiments, topic)
    
    # group tweets by date
    dates = df.groupby('date').count()
    dates['day'] = ''
    for i in range(0, len(dates.index)):
        dates['day'][i] = dates.index[i].day
    # plot tweet frequency 
    plot_frequency_time(dates, topic)
    
    # get average tweet sentiment for a time period
    sumsentiment = 0
    count = 0
    for i in range(len(df.index)):
        if df['date'].iloc[i] == df['date'].iloc[0]:
            sumsentiment += df['compound'].iloc[i]
            count += 1
    avg = sumsentiment / count
    #calculate average sentiment per day
    #https://stackoverflow.com/questions/67899247/compute-column-average-based-on-conditions-pandas
    df_avg = df.groupby(['date'], as_index=False)['compound'].mean()
    
    #add day from date as separate column
    df_avg['day'] = ''
    for i in range(0, len(df_avg.index)):
        df_avg['day'][i] = df_avg['date'][i].day

    #plot average sentiment over time
    plot_sentiment_average_time(df_avg, topic)


def plot_sentiment(df, topic):
    plt.plot(df.index, df['compound'].sort_values())
    plt.title('Topic {}: Sentiment Analysis using Vader'.format(topic))
    plt.ylabel('Polarity')
    plt.xlabel('Tweets')
    plt.savefig('../dataout/sentiment/Topic{}_sentiment1.jpeg'.format(topic))
    plt.close()

def plot_sentiment2(df, topic):
    plt.plot(df.index, df['Polarity'].sort_values())
    plt.title('Topic {}: Sentiment Analysis using Vader'.format(topic))
    plt.ylabel('Polarity')
    plt.xlabel('Tweets')
    plt.savefig('../dataout/sentiment/Topic{}_sentiment2.jpeg'.format(topic))
    plt.close()

def plot_sentiment3(sentiments, topic):
    plt.bar(sentiments.index, sentiments["compound"])
    plt.title('Topic {}: Sentiment Polarity Difference'.format(topic))
    plt.xlabel('Polarity')
    plt.ylabel('Count')
    plt.savefig('../dataout/sentiment/Topic{}_sentiment3.jpeg'.format(topic))
    plt.close()

def plot_frequency_time(dates, topic):
    #plot tweet frequency over time
    plt.plot(dates['day'], dates['cleaned_tweet'])
    plt.title('Topic {}: Tweet Frequency'.format(topic))
    plt.xlabel('Day of May 2021')
    plt.ylabel('Count of Topic4 Tweets')
    plt.savefig('../dataout/sentiment/Topic{}_frequency.jpeg'.format(topic))
    plt.close()

def plot_sentiment_average_time(df_avg, topic):
    plt.plot(df_avg['day'], df_avg['compound'])
    plt.title('Topic {}: Sentiment Over Time'.format(topic))
    plt.ylabel('Average Polarity')
    plt.xlabel('Day of May 2021')
    plt.savefig('../dataout/sentiment/Topic{}_sentiment4_time.jpeg'.format(topic))
    plt.close()

def calc_pol(x, bound):
    if x < -0.05:
        return -1
    elif x > 0.05:
        return 1
    else:
        return 0

# run for all topic
df = df_setup()
for topic in range(20):
    sentiment_analysis_per_topic(df, topic)
    
# run for one topic
# sentiment_analysis_per_topic(df, 4)
# Out:
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# <ipython-input-2-c2135a080aeb>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Polarity'] = df['corpus'].apply(pol)
# <ipython-input-2-c2135a080aeb>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
# <ipython-input-2-c2135a080aeb>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day

# %% [markdown]
# # Sentiment analysis step by step
#
# This is the above code step by step (you can see the dataframes being outputted step by step, etc)

# %%
# read in data produced by topic_modelling.ipynb
df = pd.read_csv('../datain/sentiment/cleaned_tweets_no_stopwords_and_only_letters.csv')
df = df[['Unnamed: 0', 'created_at', 'id', "cleaned_tweet"]].copy()
df = df.rename({'Unnamed: 0': 'tweet_index'}, axis=1)
df
# Out:
#         tweet_index                 created_at                   id  \
# 0                 0  2021-05-31 23:59:42+00:00  1399515966774530048
# 1                 1  2021-05-31 23:59:40+00:00  1399515957362450432
# 2                 2  2021-05-31 23:59:35+00:00  1399515936093204480
# 3                 4  2021-05-31 23:58:47+00:00  1399515734007447552
# 4                 5  2021-05-31 23:58:44+00:00  1399515723274280960
# ...             ...                        ...                  ...
# 407484       459473  2021-02-01 11:31:45+00:00  1356203583193063424
# 407485       459474  2021-02-01 11:05:55+00:00  1356197080272752640
# 407486       459475  2021-02-01 10:49:53+00:00  1356193045817872384
# 407487       459476  2021-02-01 09:29:19+00:00  1356172769424244736
# 407488       459478  2021-02-01 03:58:29+00:00  1356089513857208320
#
#                                             cleaned_tweet
# 0                                            good project
# 1                                     great project reset
# 2       beautiful project congratulations whole team h...
# 3              participating cryptoultraman airdrop round
# 4       nice find project project great invite many pe...
# ...                                                   ...
# 407484                                         dena great
# 407485                                     join gays dena
# 407486                                      great project
# 407487  rates determined higher chance worse low chanc...
# 407488                                            friends
#
# [407489 rows x 4 columns]

# %%
df['maxtopic'] = 0
df
# Out:
#         tweet_index                 created_at                   id  \
# 0                 0  2021-05-31 23:59:42+00:00  1399515966774530048
# 1                 1  2021-05-31 23:59:40+00:00  1399515957362450432
# 2                 2  2021-05-31 23:59:35+00:00  1399515936093204480
# 3                 4  2021-05-31 23:58:47+00:00  1399515734007447552
# 4                 5  2021-05-31 23:58:44+00:00  1399515723274280960
# ...             ...                        ...                  ...
# 407484       459473  2021-02-01 11:31:45+00:00  1356203583193063424
# 407485       459474  2021-02-01 11:05:55+00:00  1356197080272752640
# 407486       459475  2021-02-01 10:49:53+00:00  1356193045817872384
# 407487       459476  2021-02-01 09:29:19+00:00  1356172769424244736
# 407488       459478  2021-02-01 03:58:29+00:00  1356089513857208320
#
#                                             cleaned_tweet  maxtopic
# 0                                            good project         0
# 1                                     great project reset         0
# 2       beautiful project congratulations whole team h...         0
# 3              participating cryptoultraman airdrop round         0
# 4       nice find project project great invite many pe...         0
# ...                                                   ...       ...
# 407484                                         dena great         0
# 407485                                     join gays dena         0
# 407486                                      great project         0
# 407487  rates determined higher chance worse low chanc...         0
# 407488                                            friends         0
#
# [407489 rows x 5 columns]

# %%
# remove any null created_at values from dataframe
df = df.drop(df[df['created_at'].isnull()].index)
# ensure that all values in created_at has 2021 (and not random strings)
df = df[df['created_at'].str.contains("2021")]
df
# Out:
#         tweet_index                 created_at                   id  \
# 0                 0  2021-05-31 23:59:42+00:00  1399515966774530048
# 1                 1  2021-05-31 23:59:40+00:00  1399515957362450432
# 2                 2  2021-05-31 23:59:35+00:00  1399515936093204480
# 3                 4  2021-05-31 23:58:47+00:00  1399515734007447552
# 4                 5  2021-05-31 23:58:44+00:00  1399515723274280960
# ...             ...                        ...                  ...
# 407484       459473  2021-02-01 11:31:45+00:00  1356203583193063424
# 407485       459474  2021-02-01 11:05:55+00:00  1356197080272752640
# 407486       459475  2021-02-01 10:49:53+00:00  1356193045817872384
# 407487       459476  2021-02-01 09:29:19+00:00  1356172769424244736
# 407488       459478  2021-02-01 03:58:29+00:00  1356089513857208320
#
#                                             cleaned_tweet  maxtopic
# 0                                            good project         0
# 1                                     great project reset         0
# 2       beautiful project congratulations whole team h...         0
# 3              participating cryptoultraman airdrop round         0
# 4       nice find project project great invite many pe...         0
# ...                                                   ...       ...
# 407484                                         dena great         0
# 407485                                     join gays dena         0
# 407486                                      great project         0
# 407487  rates determined higher chance worse low chanc...         0
# 407488                                            friends         0
#
# [407489 rows x 5 columns]

# %%
df = df.drop(df[df['cleaned_tweet'].isnull()].index)

# %%
# split created_at into date and time columns
#https://intellipaat.com/community/13909/python-how-can-i-split-a-column-with-both-date-and-time-e-g-2019-07-02-00-12-32-utc-into-two-separate-columns
df['created_at'] = pd.to_datetime(df['created_at'])
df['date'] = df['created_at'].dt.date
df['time'] = df['created_at'].dt.time
df
# Out:
#         tweet_index                created_at                   id  \
# 0                 0 2021-05-31 23:59:42+00:00  1399515966774530048
# 1                 1 2021-05-31 23:59:40+00:00  1399515957362450432
# 2                 2 2021-05-31 23:59:35+00:00  1399515936093204480
# 3                 4 2021-05-31 23:58:47+00:00  1399515734007447552
# 4                 5 2021-05-31 23:58:44+00:00  1399515723274280960
# ...             ...                       ...                  ...
# 407484       459473 2021-02-01 11:31:45+00:00  1356203583193063424
# 407485       459474 2021-02-01 11:05:55+00:00  1356197080272752640
# 407486       459475 2021-02-01 10:49:53+00:00  1356193045817872384
# 407487       459476 2021-02-01 09:29:19+00:00  1356172769424244736
# 407488       459478 2021-02-01 03:58:29+00:00  1356089513857208320
#
#                                             cleaned_tweet  maxtopic  \
# 0                                            good project         0
# 1                                     great project reset         0
# 2       beautiful project congratulations whole team h...         0
# 3              participating cryptoultraman airdrop round         0
# 4       nice find project project great invite many pe...         0
# ...                                                   ...       ...
# 407484                                         dena great         0
# 407485                                     join gays dena         0
# 407486                                      great project         0
# 407487  rates determined higher chance worse low chanc...         0
# 407488                                            friends         0
#
#               date      time
# 0       2021-05-31  23:59:42
# 1       2021-05-31  23:59:40
# 2       2021-05-31  23:59:35
# 3       2021-05-31  23:58:47
# 4       2021-05-31  23:58:44
# ...            ...       ...
# 407484  2021-02-01  11:31:45
# 407485  2021-02-01  11:05:55
# 407486  2021-02-01  10:49:53
# 407487  2021-02-01  09:29:19
# 407488  2021-02-01  03:58:29
#
# [406031 rows x 7 columns]

# %%
topic = 0

# %%
df = df[df["maxtopic"] == topic]
df
# Out:
#         tweet_index                created_at                   id  \
# 0                 0 2021-05-31 23:59:42+00:00  1399515966774530048
# 1                 1 2021-05-31 23:59:40+00:00  1399515957362450432
# 2                 2 2021-05-31 23:59:35+00:00  1399515936093204480
# 3                 4 2021-05-31 23:58:47+00:00  1399515734007447552
# 4                 5 2021-05-31 23:58:44+00:00  1399515723274280960
# ...             ...                       ...                  ...
# 407484       459473 2021-02-01 11:31:45+00:00  1356203583193063424
# 407485       459474 2021-02-01 11:05:55+00:00  1356197080272752640
# 407486       459475 2021-02-01 10:49:53+00:00  1356193045817872384
# 407487       459476 2021-02-01 09:29:19+00:00  1356172769424244736
# 407488       459478 2021-02-01 03:58:29+00:00  1356089513857208320
#
#                                             cleaned_tweet  maxtopic  \
# 0                                            good project         0
# 1                                     great project reset         0
# 2       beautiful project congratulations whole team h...         0
# 3              participating cryptoultraman airdrop round         0
# 4       nice find project project great invite many pe...         0
# ...                                                   ...       ...
# 407484                                         dena great         0
# 407485                                     join gays dena         0
# 407486                                      great project         0
# 407487  rates determined higher chance worse low chanc...         0
# 407488                                            friends         0
#
#               date      time
# 0       2021-05-31  23:59:42
# 1       2021-05-31  23:59:40
# 2       2021-05-31  23:59:35
# 3       2021-05-31  23:58:47
# 4       2021-05-31  23:58:44
# ...            ...       ...
# 407484  2021-02-01  11:31:45
# 407485  2021-02-01  11:05:55
# 407486  2021-02-01  10:49:53
# 407487  2021-02-01  09:29:19
# 407488  2021-02-01  03:58:29
#
# [407489 rows x 7 columns]

# %%
analyzer = SentimentIntensityAnalyzer()
for tweet in df["cleaned_tweet"]:
    vs = analyzer.polarity_scores(tweet)
    print("{:-<65} {}".format(tweet, str(vs)))
# Out:
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# great project reset---------------------------------------------- {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6249}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# participating cryptoultraman airdrop round----------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# nice find project project great invite many people take part make project even better {'neg': 0.0, 'neu': 0.467, 'pos': 0.533, 'compound': 0.886}
# great project---------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# high reputation strong real name hope friends participate understand {'neg': 0.0, 'neu': 0.392, 'pos': 0.608, 'compound': 0.8519}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# high reputation strong real name hope friends participate understand {'neg': 0.0, 'neu': 0.392, 'pos': 0.608, 'compound': 0.8519}
# amazing project project going great future invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.9081}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# amazing project project going great future invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.9081}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# hopefully project success becomes one best cryptos enthusiastic participating also supporting good luck {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9705}
# hopefully project success becomes one best cryptos enthusiastic participating also supporting good luck {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9705}
# believe faithful------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# excellent project future strong team transparent planned project roadmap successfuli always waiting progress project {'neg': 0.0, 'neu': 0.529, 'pos': 0.471, 'compound': 0.8689}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# believe faithful------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# amazing project-------------------------------------------------- {'neg': 0.0, 'neu': 0.208, 'pos': 0.792, 'compound': 0.5859}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# like project looks like great project future let join part success project {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.9325}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# hope project extraordinary known world lucky ones get------------ {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.6908}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# good project sir------------------------------------------------- {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
# good dinosour family--------------------------------------------- {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# estou participando cryptoultraman airdrop round------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# great project---------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# elon musk th birthday party animated lottery--------------------- {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# nice project look forward growth success project----------------- {'neg': 0.0, 'neu': 0.305, 'pos': 0.695, 'compound': 0.8442}
# reset excited project hopefully project going better position future best wishes teams {'neg': 0.0, 'neu': 0.337, 'pos': 0.663, 'compound': 0.9153}
# great project---------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# nice------------------------------------------------------------- {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215}
# awesome project-------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# wow good project great project happy join airdrop project love projec reset bsc address {'neg': 0.0, 'neu': 0.277, 'pos': 0.723, 'compound': 0.9678}
# good project come see guys--------------------------------------- {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4404}
# join guys-------------------------------------------------------- {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'compound': 0.296}
# hope project success sir becomes one best cryptos enthusiastic participating also supporting good luck sir reset {'neg': 0.0, 'neu': 0.283, 'pos': 0.717, 'compound': 0.9712}
# good project join------------------------------------------------ {'neg': 0.0, 'neu': 0.164, 'pos': 0.836, 'compound': 0.6249}
# good project project going great invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.489, 'pos': 0.511, 'compound': 0.8885}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# amazing project project going great future invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.9081}
# let join smaugs good promising project forget vote smg listed latoken smg {'neg': 0.107, 'neu': 0.452, 'pos': 0.441, 'compound': 0.7096}
# good project strong potential miss guys-------------------------- {'neg': 0.148, 'neu': 0.278, 'pos': 0.574, 'compound': 0.6808}
# happy opportunity------------------------------------------------ {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.7579}
# name tuha currently available launchpad voted early stages project since time project practicing said would launch bird {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# let join smaugs good promising project forget vote smg listed latoken {'neg': 0.114, 'neu': 0.419, 'pos': 0.467, 'compound': 0.7096}
# got registered upcoming social launchpool------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# meets livx ceo conversation-------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# great project---------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# nice project deserves great hand applaud------------------------- {'neg': 0.0, 'neu': 0.132, 'pos': 0.868, 'compound': 0.9201}
# elon musk th birthday party animated lottery--------------------- {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
# weyu good project strong potential miss guys--------------------- {'neg': 0.136, 'neu': 0.339, 'pos': 0.525, 'compound': 0.6808}
# hot birds flying blockchain watch cash money brother catch flying birds {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# nice------------------------------------------------------------- {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# wow awesome project---------------------------------------------- {'neg': 0.0, 'neu': 0.112, 'pos': 0.888, 'compound': 0.836}
# good project reset----------------------------------------------- {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
# good project strong team----------------------------------------- {'neg': 0.0, 'neu': 0.244, 'pos': 0.756, 'compound': 0.7351}
# good project sir thanks------------------------------------------ {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.7003}
# elon musk th birthday party animated lottery blessings peace mind happy birthday sir elon musk long life prosperity {'neg': 0.0, 'neu': 0.511, 'pos': 0.489, 'compound': 0.9246}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# nice project reset bnb address----------------------------------- {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.4215}
# hope get chance win token future project bigger------------------ {'neg': 0.0, 'neu': 0.365, 'pos': 0.635, 'compound': 0.8271}
# good project project going great invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.489, 'pos': 0.511, 'compound': 0.8885}
# hope get airdrop moon gereat project----------------------------- {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.4404}
# nice good project free crypto coin giveaway love future---------- {'neg': 0.0, 'neu': 0.275, 'pos': 0.725, 'compound': 0.9217}
# amazing project project going great future invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.9081}
# nice projeck----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes fu {'neg': 0.149, 'neu': 0.19, 'pos': 0.661, 'compound': 0.9448}
# nice project good project participate dont miss guys------------- {'neg': 0.0, 'neu': 0.412, 'pos': 0.588, 'compound': 0.7306}
# nice project good project participate dont miss guys------------- {'neg': 0.0, 'neu': 0.412, 'pos': 0.588, 'compound': 0.7306}
# beautiful project hope makes best impact wax address------------- {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'compound': 0.9001}
# hot birds flying blockchain watch cash money brother catch flying birds {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# got registered upcoming social launchpool------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# good project project going great invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.489, 'pos': 0.511, 'compound': 0.8885}
# need winner list------------------------------------------------- {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'compound': 0.5859}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# got registered upcoming social launchpool------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# understand project know starfi good project good long term hopefully community develop {'neg': 0.0, 'neu': 0.514, 'pos': 0.486, 'compound': 0.8176}
# buy dinosour pancake--------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# thanks giving us great opportunity supporting always success development team moon kermit sol eth {'neg': 0.0, 'neu': 0.299, 'pos': 0.701, 'compound': 0.9571}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# great future----------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# great big good project wow super excellent iam happy------------- {'neg': 0.0, 'neu': 0.12, 'pos': 0.88, 'compound': 0.9723}
# interested participate airdrop project believe successful project going forward always developing {'neg': 0.0, 'neu': 0.581, 'pos': 0.419, 'compound': 0.7579}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# great project---------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# participating---------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# thanks giving us great opportunity enthusiastic participating also supporting kermit sol eth {'neg': 0.0, 'neu': 0.247, 'pos': 0.753, 'compound': 0.9538}
# good project great----------------------------------------------- {'neg': 0.0, 'neu': 0.125, 'pos': 0.875, 'compound': 0.7906}
# good project great----------------------------------------------- {'neg': 0.0, 'neu': 0.125, 'pos': 0.875, 'compound': 0.7906}
# cryptocurrency project make rich one day------------------------- {'neg': 0.0, 'neu': 0.581, 'pos': 0.419, 'compound': 0.5574}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# project going better position future thanks shared wonderful----- {'neg': 0.0, 'neu': 0.252, 'pos': 0.748, 'compound': 0.8979}
# project going better position future thanks shared wonderful----- {'neg': 0.0, 'neu': 0.252, 'pos': 0.748, 'compound': 0.8979}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# hopefully project success becomes one best cryptos enthusiastic participating also supporting good luck {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9705}
# hopefully project success becomes one best cryptos enthusiastic participating also supporting good luck {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9705}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# thanks giving us great opportunity supporting always success development team moon lets join guys {'neg': 0.0, 'neu': 0.25, 'pos': 0.75, 'compound': 0.9638}
# thanks giving us great opportunity supporting always success development team moon lets join guys {'neg': 0.0, 'neu': 0.25, 'pos': 0.75, 'compound': 0.9638}
# help win awesome competition------------------------------------- {'neg': 0.0, 'neu': 0.086, 'pos': 0.914, 'compound': 0.891}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# amazing projeck let go moon-------------------------------------- {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.5859}
# thanks giving us great opportunity supporting always success development team moon lets join guys {'neg': 0.0, 'neu': 0.25, 'pos': 0.75, 'compound': 0.9638}
# thanks giving us great opportunity supporting always success development team moon lets join guys {'neg': 0.0, 'neu': 0.25, 'pos': 0.75, 'compound': 0.9638}
# amazing project thank much weyu good luck team go go go---------- {'neg': 0.0, 'neu': 0.365, 'pos': 0.635, 'compound': 0.9042}
# nice find project project great---------------------------------- {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.7845}
# would gigantic marketplace weyu whitelist airdrop live register guaranteed airdrop {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# great project thanks opportunity--------------------------------- {'neg': 0.0, 'neu': 0.093, 'pos': 0.907, 'compound': 0.8689}
# participating airdrop tag friend hastag-------------------------- {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.4939}
# project looks interesting interested support project successful according plan set {'neg': 0.0, 'neu': 0.335, 'pos': 0.665, 'compound': 0.8979}
# got registered upcoming social launchpool------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# good project best luck sir guys please join event miss----------- {'neg': 0.079, 'neu': 0.198, 'pos': 0.723, 'compound': 0.9186}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# good project kermit sol eth-------------------------------------- {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4404}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# extremely fantastic project-------------------------------------- {'neg': 0.0, 'neu': 0.339, 'pos': 0.661, 'compound': 0.5984}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# good project future generation cryptoccurrency bsc address------- {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}
# projects verry good come join fast------------------------------- {'neg': 0.0, 'neu': 0.44, 'pos': 0.56, 'compound': 0.6249}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# good airdrop----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# participated following guidelines rules airdrop hope many people lucky get prize airdrop {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.8402}
# great project---------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# good aidrop------------------------------------------------------ {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# bakeryswap next marketplace awesome project predictable transparent road map planned projected think near future see unprecedented growth project {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.7717}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# believe project moon--------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# participating cryptoultraman airdrop round----------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# baby shark crypto legend trendy two great things come along together baby shark doo doo doo doo let go buy doo doo doo doo let go share doo doo doo doo let go moon doo doo doo doo {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.743}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# miss great opportunity guys moon--------------------------------- {'neg': 0.152, 'neu': 0.19, 'pos': 0.657, 'compound': 0.743}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# elon musk th birthday party animated lottery--------------------- {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# interested project seeing current condition animals increasingly extinct hope project continue future children {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.6808}
# interested project seeing current condition animals increasingly extinct hope project continue future children {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.6808}
# really amazing project------------------------------------------- {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.624}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# great project---------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# great project moon----------------------------------------------- {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6249}
# believe faithful------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# hi friends miss opportunity project great investment claim airdrop get ready moon let join {'neg': 0.066, 'neu': 0.329, 'pos': 0.605, 'compound': 0.9201}
# impresive great project trust project successfully--------------- {'neg': 0.0, 'neu': 0.221, 'pos': 0.779, 'compound': 0.891}
# nice project well done team happy participate amazing project---- {'neg': 0.0, 'neu': 0.287, 'pos': 0.713, 'compound': 0.9081}
# nice project well done team happy participate amazing project---- {'neg': 0.0, 'neu': 0.287, 'pos': 0.713, 'compound': 0.9081}
# amazing project great opportunity big profit future-------------- {'neg': 0.0, 'neu': 0.181, 'pos': 0.819, 'compound': 0.9274}
# lovely amazing project ever seen strong community professional team join guys {'neg': 0.0, 'neu': 0.348, 'pos': 0.652, 'compound': 0.9201}
# defi setting groundwork future financial system effective quicker rewarding aroma finance digital asset ecosystem aid control money {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'compound': 0.8402}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# think strong project thanks shared wonderful opportunity best wishes team members {'neg': 0.0, 'neu': 0.161, 'pos': 0.839, 'compound': 0.9633}
# participating---------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# think strong project thanks shared wonderful opportunity best wishes team members {'neg': 0.0, 'neu': 0.161, 'pos': 0.839, 'compound': 0.9633}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# opportunity take part airdrop enthusiastic excellent project let take moon {'neg': 0.0, 'neu': 0.419, 'pos': 0.581, 'compound': 0.8658}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# go go go guys hurry---------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# good project good airdrop---------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.7003}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# believe faithful------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# participating cryptoultraman airdrop round mark------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# elon musk th birthday party animated lottery--------------------- {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# mars project trustworthy users great future mars project greetings much success martians please send address projectmars {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound': 0.9477}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# wow good project great project happy join airdrop project love projec reset {'neg': 0.0, 'neu': 0.223, 'pos': 0.777, 'compound': 0.9678}
# device needs considered strength defending enemy attacks example using shield considerable repulsion reflected {'neg': 0.327, 'neu': 0.51, 'pos': 0.163, 'compound': -0.4939}
# help win awesome competition------------------------------------- {'neg': 0.0, 'neu': 0.086, 'pos': 0.914, 'compound': 0.891}
# participating cryptoultraman airdrop round mark------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# help win awesome competition------------------------------------- {'neg': 0.0, 'neu': 0.086, 'pos': 0.914, 'compound': 0.891}
# good project project going great invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.489, 'pos': 0.511, 'compound': 0.8885}
# good------------------------------------------------------------- {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4404}
# good project huge potential-------------------------------------- {'neg': 0.0, 'neu': 0.278, 'pos': 0.722, 'compound': 0.6369}
# good project best project---------------------------------------- {'neg': 0.0, 'neu': 0.22, 'pos': 0.78, 'compound': 0.7964}
# good project best project---------------------------------------- {'neg': 0.0, 'neu': 0.22, 'pos': 0.78, 'compound': 0.7964}
# anticipation token launch want reward community token tag influencer work cybertino details {'neg': 0.0, 'neu': 0.584, 'pos': 0.416, 'compound': 0.6597}
# amazing project great team project going huge lets support team part project guys {'neg': 0.0, 'neu': 0.411, 'pos': 0.589, 'compound': 0.9169}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# good strong project thanks opportunity--------------------------- {'neg': 0.0, 'neu': 0.078, 'pos': 0.922, 'compound': 0.8979}
# participated following guidelines rules airdrop hope many people lucky get prize airdrop thank much {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'compound': 0.8885}
# good strong project thanks opportunity--------------------------- {'neg': 0.0, 'neu': 0.078, 'pos': 0.922, 'compound': 0.8979}
# participated following guidelines rules airdrop hope many people lucky get prize airdrop thank much {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'compound': 0.8885}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# hopefully project success becomes one best cryptos enthusiastic participating also supporting good luck {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9705}
# good project amazing project sir--------------------------------- {'neg': 0.0, 'neu': 0.309, 'pos': 0.691, 'compound': 0.7717}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# believe faithful------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# believe faithful------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# believe faithful------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# well organized legit project believe project bright future happy part great project {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.9153}
# hope project success--------------------------------------------- {'neg': 0.0, 'neu': 0.132, 'pos': 0.868, 'compound': 0.765}
# help win awesome competition------------------------------------- {'neg': 0.0, 'neu': 0.086, 'pos': 0.914, 'compound': 0.891}
# hope project success sir becomes one best cryptos enthusiastic participating also supporting good luck sir {'neg': 0.0, 'neu': 0.26, 'pos': 0.74, 'compound': 0.9712}
# well organized legit project believe project bright future happy part great project {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.9153}
# believe faithful------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# amazing project thank much weyu good luck team------------------- {'neg': 0.0, 'neu': 0.247, 'pos': 0.753, 'compound': 0.9042}
# thanks airdrop--------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# lucky lets wait watch btw ita great project kermit sol eth------- {'neg': 0.0, 'neu': 0.566, 'pos': 0.434, 'compound': 0.7845}
# hope project success--------------------------------------------- {'neg': 0.0, 'neu': 0.132, 'pos': 0.868, 'compound': 0.765}
# good airdrop----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# great project kindly follow great project------------------------ {'neg': 0.0, 'neu': 0.208, 'pos': 0.792, 'compound': 0.9081}
# great project kindly follow great project------------------------ {'neg': 0.0, 'neu': 0.208, 'pos': 0.792, 'compound': 0.9081}
# participating---------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# really appreciatable project happy apart would achieve great success future great wishes project {'neg': 0.0, 'neu': 0.314, 'pos': 0.686, 'compound': 0.955}
# really appreciatable project happy apart would achieve great success future great wishes project {'neg': 0.0, 'neu': 0.314, 'pos': 0.686, 'compound': 0.955}
# thanks shared wonderful opportunity hopefully project going better position future best wishes teams {'neg': 0.0, 'neu': 0.177, 'pos': 0.823, 'compound': 0.969}
# well organized legit project believe project bright future happy part great project {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.9153}
# super project---------------------------------------------------- {'neg': 0.0, 'neu': 0.204, 'pos': 0.796, 'compound': 0.5994}
# good project project going great invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.489, 'pos': 0.511, 'compound': 0.8885}
# good project project going great invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.489, 'pos': 0.511, 'compound': 0.8885}
# help win awesome competition------------------------------------- {'neg': 0.0, 'neu': 0.086, 'pos': 0.914, 'compound': 0.891}
# absolutely great airdrop anda great project weyu always successful wish best guys {'neg': 0.0, 'neu': 0.267, 'pos': 0.733, 'compound': 0.9647}
# wow good project great project happy join airdrop project love projec reset bsc address {'neg': 0.0, 'neu': 0.277, 'pos': 0.723, 'compound': 0.9678}
# elon musk th birthday party animated lottery--------------------- {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# love project reset bsc address----------------------------------- {'neg': 0.0, 'neu': 0.488, 'pos': 0.512, 'compound': 0.6369}
# love project reset bsc address----------------------------------- {'neg': 0.0, 'neu': 0.488, 'pos': 0.512, 'compound': 0.6369}
# highly planned airdrop impressive good looking------------------- {'neg': 0.0, 'neu': 0.382, 'pos': 0.618, 'compound': 0.7553}
# join anticipated project ever weyu whitelist airdrop live register guaranteed airdrop {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.296}
# thanks giving us great opportunity supporting always success development team moon great project {'neg': 0.0, 'neu': 0.208, 'pos': 0.792, 'compound': 0.9716}
# great one project------------------------------------------------ {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6249}
# great one project------------------------------------------------ {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6249}
# moon soon regrets holding join----------------------------------- {'neg': 0.325, 'neu': 0.39, 'pos': 0.286, 'compound': -0.0772}
# amazing project project going great future invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.9081}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# goodproject------------------------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# participating---------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# think strong project thanks shared wonderful opportunity best wishes team members {'neg': 0.0, 'neu': 0.161, 'pos': 0.839, 'compound': 0.9633}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# good project strong team predictable transparent road map planned projected {'neg': 0.0, 'neu': 0.563, 'pos': 0.437, 'compound': 0.7351}
# good project strong team predictable transparent road map planned projected {'neg': 0.0, 'neu': 0.563, 'pos': 0.437, 'compound': 0.7351}
# help win awesome competition------------------------------------- {'neg': 0.0, 'neu': 0.086, 'pos': 0.914, 'compound': 0.891}
# amazing project project going great future invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.9081}
# hope project success sir becomes one best cryptos enthusiastic participating also supporting good luck sir {'neg': 0.0, 'neu': 0.26, 'pos': 0.74, 'compound': 0.9712}
# join project----------------------------------------------------- {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'compound': 0.296}
# fantastic project hope biggest one someday thanks teamwork ans team project goes {'neg': 0.0, 'neu': 0.489, 'pos': 0.511, 'compound': 0.8555}
# great project wonderfull team im proud project lets moon join guys ltf {'neg': 0.0, 'neu': 0.489, 'pos': 0.511, 'compound': 0.8555}
# nice project look forward growth success project----------------- {'neg': 0.0, 'neu': 0.305, 'pos': 0.695, 'compound': 0.8442}
# separate asset part could better embraced participating work funds could get large part work make profits great community understands real life utility necessity defidefense love share view {'neg': 0.0, 'neu': 0.528, 'pos': 0.472, 'compound': 0.9571}
# great project---------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# participating cryptoultraman airdrop round----------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# go moon---------------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# greattt---------------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# project good potential future good gaming bsc address------------ {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.7003}
# check project---------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# understand project know starfi good project good project--------- {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.7003}
# huge project promising future make community enjoy great opportunities {'neg': 0.0, 'neu': 0.212, 'pos': 0.788, 'compound': 0.9313}
# participating---------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# hope project success becomes one best cryptos enthusiastic participating also supporting {'neg': 0.0, 'neu': 0.262, 'pos': 0.738, 'compound': 0.9509}
# coming soon yugioh store magic cards collectibles yugioh cards uniqueness character {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# never give starting continue heart says surely support keep spirit {'neg': 0.0, 'neu': 0.343, 'pos': 0.657, 'compound': 0.8885}
# nice project hold------------------------------------------------ {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.4215}
# nice project hold------------------------------------------------ {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.4215}
# help win awesome competition------------------------------------- {'neg': 0.0, 'neu': 0.086, 'pos': 0.914, 'compound': 0.891}
# huge project promising future make community enjoy great opportunities {'neg': 0.0, 'neu': 0.212, 'pos': 0.788, 'compound': 0.9313}
# glad join community airdrop thanks chance im believe nice project future come lets join {'neg': 0.0, 'neu': 0.346, 'pos': 0.654, 'compound': 0.9201}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# elon musk th birthday party animated lottery--------------------- {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
# opportunity take part airdrop enthusiastic excellent project let take moon {'neg': 0.0, 'neu': 0.419, 'pos': 0.581, 'compound': 0.8658}
# great project---------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# anticipate next-------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# participating airdrop-------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# elon musk th birthday party animated lottery--------------------- {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
# believe faithful------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# welcome join official communities website telegramcommunity twitter instagram support {'neg': 0.0, 'neu': 0.432, 'pos': 0.568, 'compound': 0.7845}
# amazing projects pretty cool join limited time fast-------------- {'neg': 0.116, 'neu': 0.183, 'pos': 0.701, 'compound': 0.8625}
# wow good news---------------------------------------------------- {'neg': 0.0, 'neu': 0.13, 'pos': 0.87, 'compound': 0.7717}
# got registered upcoming social launchpool------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# guys follow twitter always giveaway free------------------------- {'neg': 0.0, 'neu': 0.602, 'pos': 0.398, 'compound': 0.5106}
# elon musk th birthday party animated lottery--------------------- {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# huge project promising future make community enjoy great opportunities potentials {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9313}
# excellent project great project project goes high future make us rich short time fully supported excellent project {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound': 0.9582}
# participating---------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# beautiful project congratulations whole team highly appreciated visionary thought project best wishes future {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.9677}
# nice project moon go go go moon---------------------------------- {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.4215}
# project looks interesting interested support project successful according plan set {'neg': 0.0, 'neu': 0.335, 'pos': 0.665, 'compound': 0.8979}
# come join sir weyu whitelist airdrop ggoing live----------------- {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.296}
# project implemented professionally clear development plan made intelligence experts team without doubt one best project {'neg': 0.0, 'neu': 0.478, 'pos': 0.522, 'compound': 0.9003}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# good project----------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# project implemented professionally clear development plan made intelligence experts team without doubt one best project {'neg': 0.0, 'neu': 0.478, 'pos': 0.522, 'compound': 0.9003}
# believe faithful------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# project bright future really think project perfect true cool innovative project {'neg': 0.0, 'neu': 0.288, 'pos': 0.712, 'compound': 0.9308}
# currency btc----------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# replying thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.242, 'pos': 0.758, 'compound': 0.9571}
# participating airdrop check guys--------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# wow good airdrop project think good legit project love like project tag friends {'neg': 0.0, 'neu': 0.265, 'pos': 0.735, 'compound': 0.9607}
# weyu good project strong potential miss guys--------------------- {'neg': 0.136, 'neu': 0.339, 'pos': 0.525, 'compound': 0.6808}
# definitely win deep promise chest win vote quickly would like thank members project giving us opportunity vote smg {'neg': 0.0, 'neu': 0.305, 'pos': 0.695, 'compound': 0.9674}
# definitely win deep promise chest win vote quickly would like thank members project giving us opportunity vote smg {'neg': 0.0, 'neu': 0.305, 'pos': 0.695, 'compound': 0.9674}
# amazing project project going great future invite alot people take part order make project even better {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.9081}
# believe faithful------------------------------------------------- {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# thanks giving us great opportunity supporting always success development team moon {'neg': 0.0, 'neu': 0.21, 'pos': 0.79, 'compound': 0.9571}
# nice project----------------------------------------------------- {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# participating---------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# great project trust project super success soon------------------- {'neg': 0.0, 'neu': 0.167, 'pos': 0.833, 'compound': 0.9432}
# great project---------------------------------------------------- {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# weyu good project------------------------------------------------ {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
# hope project success sir becomes one best cryptos enthusiastic participating also supporting good luck sir {'neg': 0.0, 'neu': 0.26, 'pos': 0.74, 'compound': 0.9712}
# hope project success sir becomes one best cryptos enthusiastic participating also supporting good luck sir {'neg': 0.0, 'neu': 0.26, 'pos': 0.74, 'compound': 0.9712}
# nice------------------------------------------------------------- {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215}
# participating---------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# nice project strong team----------------------------------------- {'neg': 0.0, 'neu': 0.247, 'pos': 0.753, 'compound': 0.7269}
# like retweet gate twitter pinned post comment participating tag friends airdrop hashtags {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'compound': 0.6808}
# nice project look forward growth success project----------------- {'neg': 0.0, 'neu': 0.305, 'pos': 0.695, 'compound': 0.8442}
# hopefully future always successful developerthumbs wish luckrelieved face {'neg': 0.0, 'neu': 0.352, 'pos': 0.648, 'compound': 0.8481}
# weyu good project strong potential miss guys--------------------- {'neg': 0.136, 'neu': 0.339, 'pos': 0.525, 'compound': 0.6808}
# help win awesome competition------------------------------------- {'neg': 0.0, 'neu': 0.086, 'pos': 0.914, 'compound': 0.891}
# participating---------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# project useful future supported professional team---------------- {'neg': 0.0, 'neu': 0.435, 'pos': 0.565, 'compound': 0.6369}
# amazing project-------------------------------------------------- {'neg': 0.0, 'neu': 0.208, 'pos': 0.792, 'compound': 0.5859}
# amazing project-------------------------------------------------- {'neg': 0.0, 'neu': 0.208, 'pos': 0.792, 'compound': 0.5859}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16492/1157737516.py in <module>
#       2 for tweet in df["cleaned_tweet"]:
#       3     type(tweet)
# ----> 4     vs = analyzer.polarity_scores(tweet)
#       5     print("{:-<65} {}".format(tweet, str(vs)))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\vaderSentiment\vaderSentiment.py in polarity_scores(self, text)
#     239         text_no_emoji = ""
#     240         prev_space = True
# --> 241         for chr in text:
#     242             if chr in self.emojis:
#     243                 # get the textual description
#
# TypeError: 'float' object is not iterable

# %%
df["cleaned_tweet"]
# Out:
# 0                                              good project
# 1                                       great project reset
# 2         beautiful project congratulations whole team h...
# 3                participating cryptoultraman airdrop round
# 4         nice find project project great invite many pe...
#                                 ...
# 407484                                           dena great
# 407485                                       join gays dena
# 407486                                        great project
# 407487    rates determined higher chance worse low chanc...
# 407488                                              friends
# Name: cleaned_tweet, Length: 407489, dtype: object

# %%
df["corpus"]
# Out:
# 7404     @Smart_NFT_News @hodooicom Such a perfect pick...
# 7405     “I am participating in @https://twitter.com/nf...
# 7406     @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407     I am participating in @nftgateio airdrop\n\n@R...
# 7408     “I am participating in @https://twitter.com/nf...
#                                ...
# 11689    @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690    I am participating in @https://twitter.com/nft...
# 11691    @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692    Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693    @DCryptoQueen @llxxppgg Incredible project \n@...
# Name: corpus, Length: 4290, dtype: object

# %%
# check whether there are any null values in cleaned_tweet
df[df["cleaned_tweet"].isnull()]
# Out:
#       tweet_index          created_at  maxtopic  \
# 8240        22072 2021-05-25 22:30:14         4
#
#                                                  corpus cleaned_tweet  \
# 8240  @Bitboy_Crypto @TribeOneDeFi a unique platform...           NaN
#
#             date      time
# 8240  2021-05-25  22:30:14

# %%
# remove all NaN values from cleaned_tweet
df = df.drop(df[df["cleaned_tweet"].isnull()].index)
df
# Out:
#        tweet_index          created_at  maxtopic  \
# 7404         21493 2021-05-26 03:08:21         4
# 7405         11565 2021-05-28 16:27:24         4
# 7406         27952 2021-05-24 17:24:29         4
# 7407         21397 2021-05-26 03:49:04         4
# 7408         21488 2021-05-26 03:11:09         4
# ...            ...                 ...       ...
# 11689         1967 2021-05-31 12:05:29         4
# 11690         8885 2021-05-29 14:04:12         4
# 11691         1865 2021-05-31 12:38:41         4
# 11692         1847 2021-05-31 12:42:45         4
# 11693         1988 2021-05-31 12:01:05         4
#
#                                                   corpus  \
# 7404   @Smart_NFT_News @hodooicom Such a perfect pick...
# 7405   “I am participating in @https://twitter.com/nf...
# 7406   @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407   I am participating in @nftgateio airdrop\n\n@R...
# 7408   “I am participating in @https://twitter.com/nf...
# ...                                                  ...
# 11689  @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690  I am participating in @https://twitter.com/nft...
# 11691  @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692  Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693  @DCryptoQueen @llxxppgg Incredible project \n@...
#
#                                            cleaned_tweet        date      time
# 7404   such a perfect pick for your marketing gold st...  2021-05-26  03:08:21
# 7405   i am participating in twitter com nftgateio ai...  2021-05-28  16:27:24
# 7406   road to nowhere loop animation with loop sound...  2021-05-24  17:24:29
# 7407                       i am participating in airdrop  2021-05-26  03:49:04
# 7408   i am participating in twitter com nftgateio ai...  2021-05-26  03:11:09
# ...                                                  ...         ...       ...
# 11689                                          thank you  2021-05-31  12:05:29
# 11690  i am participating in twitter com nftgateio ai...  2021-05-29  14:04:12
# 11691                  nice airdrop join airdrop with me  2021-05-31  12:38:41
# 11692                                follow this project  2021-05-31  12:42:45
# 11693                        incredible project w ra wam  2021-05-31  12:01:05
#
# [4289 rows x 7 columns]

# %%
#https://github.com/sidneykung/twitter_hate_speech_detection/blob/master/preprocessing/VADER_sentiment.ipynb
pol = lambda x: analyzer.polarity_scores(x)
df['Polarity'] = df["cleaned_tweet"].apply(pol)
df
# Out:
#        tweet_index          created_at  maxtopic  \
# 7404         21493 2021-05-26 03:08:21         4
# 7405         11565 2021-05-28 16:27:24         4
# 7406         27952 2021-05-24 17:24:29         4
# 7407         21397 2021-05-26 03:49:04         4
# 7408         21488 2021-05-26 03:11:09         4
# ...            ...                 ...       ...
# 11689         1967 2021-05-31 12:05:29         4
# 11690         8885 2021-05-29 14:04:12         4
# 11691         1865 2021-05-31 12:38:41         4
# 11692         1847 2021-05-31 12:42:45         4
# 11693         1988 2021-05-31 12:01:05         4
#
#                                                   corpus  \
# 7404   @Smart_NFT_News @hodooicom Such a perfect pick...
# 7405   “I am participating in @https://twitter.com/nf...
# 7406   @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407   I am participating in @nftgateio airdrop\n\n@R...
# 7408   “I am participating in @https://twitter.com/nf...
# ...                                                  ...
# 11689  @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690  I am participating in @https://twitter.com/nft...
# 11691  @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692  Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693  @DCryptoQueen @llxxppgg Incredible project \n@...
#
#                                            cleaned_tweet        date  \
# 7404   such a perfect pick for your marketing gold st...  2021-05-26
# 7405   i am participating in twitter com nftgateio ai...  2021-05-28
# 7406   road to nowhere loop animation with loop sound...  2021-05-24
# 7407                       i am participating in airdrop  2021-05-26
# 7408   i am participating in twitter com nftgateio ai...  2021-05-26
# ...                                                  ...         ...
# 11689                                          thank you  2021-05-31
# 11690  i am participating in twitter com nftgateio ai...  2021-05-29
# 11691                  nice airdrop join airdrop with me  2021-05-31
# 11692                                follow this project  2021-05-31
# 11693                        incredible project w ra wam  2021-05-31
#
#            time                                           Polarity
# 7404   03:08:21  {'neg': 0.0, 'neu': 0.658, 'pos': 0.342, 'comp...
# 7405   16:27:24  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...
# 7406   17:24:29  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7407   03:49:04  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7408   03:11:09  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...         ...                                                ...
# 11689  12:05:29  {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'comp...
# 11690  14:04:12  {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'comp...
# 11691  12:38:41  {'neg': 0.0, 'neu': 0.444, 'pos': 0.556, 'comp...
# 11692  12:42:45  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 11693  12:01:05  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [4289 rows x 8 columns]

# %%
df = pd.concat([df.drop(['Polarity'], axis=1), df['Polarity'].apply(pd.Series)], axis=1)
df
# Out:
#        tweet_index          created_at  maxtopic  \
# 7404         21493 2021-05-26 03:08:21         4
# 7405         11565 2021-05-28 16:27:24         4
# 7406         27952 2021-05-24 17:24:29         4
# 7407         21397 2021-05-26 03:49:04         4
# 7408         21488 2021-05-26 03:11:09         4
# ...            ...                 ...       ...
# 11689         1967 2021-05-31 12:05:29         4
# 11690         8885 2021-05-29 14:04:12         4
# 11691         1865 2021-05-31 12:38:41         4
# 11692         1847 2021-05-31 12:42:45         4
# 11693         1988 2021-05-31 12:01:05         4
#
#                                                   corpus  \
# 7404   @Smart_NFT_News @hodooicom Such a perfect pick...
# 7405   “I am participating in @https://twitter.com/nf...
# 7406   @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407   I am participating in @nftgateio airdrop\n\n@R...
# 7408   “I am participating in @https://twitter.com/nf...
# ...                                                  ...
# 11689  @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690  I am participating in @https://twitter.com/nft...
# 11691  @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692  Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693  @DCryptoQueen @llxxppgg Incredible project \n@...
#
#                                            cleaned_tweet        date  \
# 7404   such a perfect pick for your marketing gold st...  2021-05-26
# 7405   i am participating in twitter com nftgateio ai...  2021-05-28
# 7406   road to nowhere loop animation with loop sound...  2021-05-24
# 7407                       i am participating in airdrop  2021-05-26
# 7408   i am participating in twitter com nftgateio ai...  2021-05-26
# ...                                                  ...         ...
# 11689                                          thank you  2021-05-31
# 11690  i am participating in twitter com nftgateio ai...  2021-05-29
# 11691                  nice airdrop join airdrop with me  2021-05-31
# 11692                                follow this project  2021-05-31
# 11693                        incredible project w ra wam  2021-05-31
#
#            time  neg    neu    pos  compound
# 7404   03:08:21  0.0  0.658  0.342    0.8316
# 7405   16:27:24  0.0  0.807  0.193    0.4767
# 7406   17:24:29  0.0  1.000  0.000    0.0000
# 7407   03:49:04  0.0  1.000  0.000    0.0000
# 7408   03:11:09  0.0  1.000  0.000    0.0000
# ...         ...  ...    ...    ...       ...
# 11689  12:05:29  0.0  0.286  0.714    0.3612
# 11690  14:04:12  0.0  0.763  0.237    0.4215
# 11691  12:38:41  0.0  0.444  0.556    0.6124
# 11692  12:42:45  0.0  1.000  0.000    0.0000
# 11693  12:01:05  0.0  1.000  0.000    0.0000
#
# [4289 rows x 11 columns]

# %%
plt.plot(df.index, df['compound'].sort_values())
plt.title('Topic {}: Sentiment Analysis using Vader'.format(topic))
plt.ylabel('Polarity')
plt.xlabel('Tweets')
# Out:
# Text(0.5, 0, 'Tweets')

# %%
def calc_polarity(x, bound):
    if x < -0.05:
        return -1
    elif x > 0.05:
        return 1
    else:
        return 0

round_pol = lambda x: calc_polarity(x, 0.05)

# %%
df['compound']
# Out:
# 7404     0.8316
# 7405     0.4767
# 7406     0.0000
# 7407     0.0000
# 7408     0.0000
#           ...
# 11689    0.3612
# 11690    0.4215
# 11691    0.6124
# 11692    0.0000
# 11693    0.0000
# Name: compound, Length: 4289, dtype: float64

# %%
df['Polarity'] = df['compound'].apply(round_pol)
df
# Out:
#        tweet_index          created_at  maxtopic  \
# 7404         21493 2021-05-26 03:08:21         4
# 7405         11565 2021-05-28 16:27:24         4
# 7406         27952 2021-05-24 17:24:29         4
# 7407         21397 2021-05-26 03:49:04         4
# 7408         21488 2021-05-26 03:11:09         4
# ...            ...                 ...       ...
# 11689         1967 2021-05-31 12:05:29         4
# 11690         8885 2021-05-29 14:04:12         4
# 11691         1865 2021-05-31 12:38:41         4
# 11692         1847 2021-05-31 12:42:45         4
# 11693         1988 2021-05-31 12:01:05         4
#
#                                                   corpus  \
# 7404   @Smart_NFT_News @hodooicom Such a perfect pick...
# 7405   “I am participating in @https://twitter.com/nf...
# 7406   @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407   I am participating in @nftgateio airdrop\n\n@R...
# 7408   “I am participating in @https://twitter.com/nf...
# ...                                                  ...
# 11689  @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690  I am participating in @https://twitter.com/nft...
# 11691  @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692  Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693  @DCryptoQueen @llxxppgg Incredible project \n@...
#
#                                            cleaned_tweet        date  \
# 7404   such a perfect pick for your marketing gold st...  2021-05-26
# 7405   i am participating in twitter com nftgateio ai...  2021-05-28
# 7406   road to nowhere loop animation with loop sound...  2021-05-24
# 7407                       i am participating in airdrop  2021-05-26
# 7408   i am participating in twitter com nftgateio ai...  2021-05-26
# ...                                                  ...         ...
# 11689                                          thank you  2021-05-31
# 11690  i am participating in twitter com nftgateio ai...  2021-05-29
# 11691                  nice airdrop join airdrop with me  2021-05-31
# 11692                                follow this project  2021-05-31
# 11693                        incredible project w ra wam  2021-05-31
#
#            time  neg    neu    pos  compound  Polarity
# 7404   03:08:21  0.0  0.658  0.342    0.8316         1
# 7405   16:27:24  0.0  0.807  0.193    0.4767         1
# 7406   17:24:29  0.0  1.000  0.000    0.0000         0
# 7407   03:49:04  0.0  1.000  0.000    0.0000         0
# 7408   03:11:09  0.0  1.000  0.000    0.0000         0
# ...         ...  ...    ...    ...       ...       ...
# 11689  12:05:29  0.0  0.286  0.714    0.3612         1
# 11690  14:04:12  0.0  0.763  0.237    0.4215         1
# 11691  12:38:41  0.0  0.444  0.556    0.6124         1
# 11692  12:42:45  0.0  1.000  0.000    0.0000         0
# 11693  12:01:05  0.0  1.000  0.000    0.0000         0
#
# [4289 rows x 12 columns]

# %% [markdown]
# # Plot Results

# %%
plt.plot(df.index, df['Polarity'].sort_values())
plt.title('Topic {}: Sentiment Analysis using Vader'.format(topic))
plt.ylabel('Polarity')
plt.xlabel('Tweets')
# Out:
# Text(0.5, 0, 'Tweets')

# %%
sentiments = df.groupby('Polarity').count()
sentiments
# Out:
#           tweet_index  created_at  maxtopic  corpus  cleaned_tweet  date  \
# Polarity
# -1                 98          98        98      98             98    98
#  0               1811        1811      1811    1811           1811  1811
#  1               2380        2380      2380    2380           2380  2380
#
#           time   neg   neu   pos  compound
# Polarity
# -1          98    98    98    98        98
#  0        1811  1811  1811  1811      1811
#  1        2380  2380  2380  2380      2380

# %%
plt.bar(sentiments.index, sentiments["compound"])
plt.title('Topic {}: Sentiment'.format(topic))
plt.xlabel('Polarity')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#group tweets by date
dates = df.groupby('date').count()
dates
# Out:
#             tweet_index  created_at  maxtopic  corpus  cleaned_tweet  time  \
# date
# 2021-05-23           41          41        41      41             41    41
# 2021-05-24          233         233       233     233            233   233
# 2021-05-25          654         654       654     654            654   654
# 2021-05-26          687         687       687     687            687   687
# 2021-05-27          269         269       269     269            269   269
# 2021-05-28          580         580       580     580            580   580
# 2021-05-29          463         463       463     463            463   463
# 2021-05-30          514         514       514     514            514   514
# 2021-05-31          848         848       848     848            848   848
#
#             neg  neu  pos  compound  Polarity
# date
# 2021-05-23   41   41   41        41        41
# 2021-05-24  233  233  233       233       233
# 2021-05-25  654  654  654       654       654
# 2021-05-26  687  687  687       687       687
# 2021-05-27  269  269  269       269       269
# 2021-05-28  580  580  580       580       580
# 2021-05-29  463  463  463       463       463
# 2021-05-30  514  514  514       514       514
# 2021-05-31  848  848  848       848       848

# %%
dates.index
# Out:
# Index([2021-05-23, 2021-05-24, 2021-05-25, 2021-05-26, 2021-05-27, 2021-05-28,
#        2021-05-29, 2021-05-30, 2021-05-31],
#       dtype='object', name='date')

# %%
dates['day'] = ''
for i in range(0, len(dates.index)):
    dates['day'][i] = dates.index[i].day
dates
# Out:
# <ipython-input-24-3887fc99946e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dates['day'][i] = dates.index[i].day
#             tweet_index  created_at  maxtopic  corpus  cleaned_tweet  time  \
# date
# 2021-05-23           41          41        41      41             41    41
# 2021-05-24          233         233       233     233            233   233
# 2021-05-25          654         654       654     654            654   654
# 2021-05-26          687         687       687     687            687   687
# 2021-05-27          269         269       269     269            269   269
# 2021-05-28          580         580       580     580            580   580
# 2021-05-29          463         463       463     463            463   463
# 2021-05-30          514         514       514     514            514   514
# 2021-05-31          848         848       848     848            848   848
#
#             neg  neu  pos  compound  Polarity day
# date
# 2021-05-23   41   41   41        41        41  23
# 2021-05-24  233  233  233       233       233  24
# 2021-05-25  654  654  654       654       654  25
# 2021-05-26  687  687  687       687       687  26
# 2021-05-27  269  269  269       269       269  27
# 2021-05-28  580  580  580       580       580  28
# 2021-05-29  463  463  463       463       463  29
# 2021-05-30  514  514  514       514       514  30
# 2021-05-31  848  848  848       848       848  31

# %%
#plot tweet frequency over time
plt.plot(dates['day'], dates['cleaned_tweet'])
plt.title('Topic4 Tweet Frequency')
plt.xlabel('Day of May 2021')
plt.ylabel('Count of Topic4 Tweets')
# Out:
# Text(0, 0.5, 'Count of Topic4 Tweets')

# %%
df
# Out:
#        tweet_index          created_at  maxtopic  \
# 7404         21493 2021-05-26 03:08:21         4
# 7405         11565 2021-05-28 16:27:24         4
# 7406         27952 2021-05-24 17:24:29         4
# 7407         21397 2021-05-26 03:49:04         4
# 7408         21488 2021-05-26 03:11:09         4
# ...            ...                 ...       ...
# 11689         1967 2021-05-31 12:05:29         4
# 11690         8885 2021-05-29 14:04:12         4
# 11691         1865 2021-05-31 12:38:41         4
# 11692         1847 2021-05-31 12:42:45         4
# 11693         1988 2021-05-31 12:01:05         4
#
#                                                   corpus  \
# 7404   @Smart_NFT_News @hodooicom Such a perfect pick...
# 7405   “I am participating in @https://twitter.com/nf...
# 7406   @ArtiFi_NFT_ "Road to Nowhere" \n\nLoop animat...
# 7407   I am participating in @nftgateio airdrop\n\n@R...
# 7408   “I am participating in @https://twitter.com/nf...
# ...                                                  ...
# 11689  @martinraskovsky @hicetnunc2000 @bernizeck @by...
# 11690  I am participating in @https://twitter.com/nft...
# 11691  @savanikalui4466 @Michell50189464 @anchaohanh1...
# 11692  Follow this project!!\n@Quangnguyen9999 @thanh...
# 11693  @DCryptoQueen @llxxppgg Incredible project \n@...
#
#                                            cleaned_tweet        date  \
# 7404   such a perfect pick for your marketing gold st...  2021-05-26
# 7405   i am participating in twitter com nftgateio ai...  2021-05-28
# 7406   road to nowhere loop animation with loop sound...  2021-05-24
# 7407                       i am participating in airdrop  2021-05-26
# 7408   i am participating in twitter com nftgateio ai...  2021-05-26
# ...                                                  ...         ...
# 11689                                          thank you  2021-05-31
# 11690  i am participating in twitter com nftgateio ai...  2021-05-29
# 11691                  nice airdrop join airdrop with me  2021-05-31
# 11692                                follow this project  2021-05-31
# 11693                        incredible project w ra wam  2021-05-31
#
#            time  neg    neu    pos  compound  Polarity
# 7404   03:08:21  0.0  0.658  0.342    0.8316         1
# 7405   16:27:24  0.0  0.807  0.193    0.4767         1
# 7406   17:24:29  0.0  1.000  0.000    0.0000         0
# 7407   03:49:04  0.0  1.000  0.000    0.0000         0
# 7408   03:11:09  0.0  1.000  0.000    0.0000         0
# ...         ...  ...    ...    ...       ...       ...
# 11689  12:05:29  0.0  0.286  0.714    0.3612         1
# 11690  14:04:12  0.0  0.763  0.237    0.4215         1
# 11691  12:38:41  0.0  0.444  0.556    0.6124         1
# 11692  12:42:45  0.0  1.000  0.000    0.0000         0
# 11693  12:01:05  0.0  1.000  0.000    0.0000         0
#
# [4289 rows x 12 columns]

# %%
df['date'].iloc[4287] == df['date'].iloc[4288]
# Out:
# True

# %%
df['compound'].iloc[0]
# Out:
# 0.8316

# %%
len(df.index)
# Out:
# 4289

# %%
sumsentiment = 0
count = 0
for i in range(len(df.index)):
    if df['date'].iloc[i] == df['date'].iloc[0]:
        sumsentiment += df['compound'].iloc[i]
        count += 1
avg = sumsentiment / count
# print(df['date'].iloc[0])
avg
# Out:
# 0.34505123726346526

# %%
#calculate average sentiment per day
#https://stackoverflow.com/questions/67899247/compute-column-average-based-on-conditions-pandas
df_avg = df.groupby(['date'], as_index=False)['compound'].mean()
df_avg
# Out:
#          date  compound
# 0  2021-05-23  0.343083
# 1  2021-05-24  0.354258
# 2  2021-05-25  0.388533
# 3  2021-05-26  0.345051
# 4  2021-05-27  0.369923
# 5  2021-05-28  0.279810
# 6  2021-05-29  0.253230
# 7  2021-05-30  0.261841
# 8  2021-05-31  0.299849

# %%
#add day from date as separate column
df_avg['day'] = ''
for i in range(0, len(df_avg.index)):
    df_avg['day'][i] = df_avg['date'][i].day

#plot average sentiment over time
plt.plot(df_avg['day'], df_avg['compound'])
plt.title('Topic4 Sentiment Over Time')
plt.ylabel('Average Polarity')
plt.xlabel('Day of May 2021')
# Out:
# <ipython-input-32-8dbd596dc9c3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg['day'][i] = df_avg['date'][i].day
# Text(0.5, 0, 'Day of May 2021')
