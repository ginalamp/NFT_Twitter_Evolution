# %% [markdown]
# # Twitter Crypto Clean Corpus
#
# Outputs corpus, cleaned tweets with their createdAt timestamps into a csv.
#
# Currently does not stem or remove stop words (code is written for it - the user just needs to set the appropriate booleans to True in In[3].

# %%
# !pip3 install nltk
import pandas as pd
import re
import html
import nltk
# nltk.download() # run this the first time you run nltk
from nltk.corpus import stopwords
from nltk import PorterStemmer

# %%
#import the data
# file_path = input("File path to json file containing twitter dataset to be cleaned?")
file_path = "datain/clean/sample100k.jsonl"
data = pd.read_json(file_path, lines=True)

# get first 100k lines of a larger dataset
# data = data.iloc[0:100000] # select first 100k entries of input file

# clean data: remove retweets and select only english tweets
data = data[~data["text"].apply(lambda x: x.startswith("RT"))]
data = data[data["lang"].apply(lambda x: x == "en")]
data
# Out:
#       lang reply_settings                                     public_metrics  \
# 0       en       everyone  {'retweet_count': 18, 'reply_count': 1, 'like_...
# 1       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 3       en       everyone  {'retweet_count': 3, 'reply_count': 0, 'like_c...
# 4       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...    ...            ...                                                ...
# 30519   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 30520   en       everyone  {'retweet_count': 0, 'reply_count': 2, 'like_c...
# 30521   en       everyone  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 30522   en       everyone  {'retweet_count': 1, 'reply_count': 3, 'like_c...
# 30523   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                     text  possibly_sensitive  \
# 0      Spud4steem | My first participation (June 1, 2...               False
# 1      nice project\n#BSC\n@DinoSour\n#NFT\n\n@NeerJa...               False
# 2      @DinoSourFamily @BinanceChain hopefully this p...               False
# 3      Love in the Time of Chaos\n\n8 editions left, ...               False
# 4      “Navigate the net ” for sale on @withFND! 🌐\n\...               False
# ...                                                  ...                 ...
# 30519  An interesting project with great prospects! A...               False
# 30520  @SpacedPainter @BullishBape No. I didn’t give ...               False
# 30521  @ethernaal Very good project\n\nJoin now my fr...               False
# 30522  Few more weeks i can tell my wife about my #nf...               False
# 30523  I liked  this project \n#NFT #NFTcommunity $WE...               False
#
#                created_at            author_id      conversation_id  \
# 0     2021-05-31 23:59:26  1261710044695052288  1399515896490696704
# 1     2021-05-31 23:58:12           3162743833  1399515589073281024
# 2     2021-05-31 23:57:08  1284100562766557184  1399264273423998976
# 3     2021-05-31 23:56:43  1277381079196893184  1399515214039732224
# 4     2021-05-31 23:56:06           1720966220  1399515060469383168
# ...                   ...                  ...                  ...
# 30519 2021-05-23 16:49:38  1318242727977312256  1396508632364195840
# 30520 2021-05-23 16:48:41   743287719124557824  1396495484538216448
# 30521 2021-05-23 16:48:23  1382143520354435072  1394987725913219072
# 30522 2021-05-23 16:48:23            262938662  1396508316533149696
# 30523 2021-05-23 16:48:22  1222954846002671616  1396508314377154560
#
#                                        referenced_tweets                   id  \
# 0                                                   None  1399515896490696704
# 1      [{'type': 'quoted', 'id': '1398724336345776132'}]  1399515589073281024
# 2      [{'type': 'replied_to', 'id': '139926427342399...  1399515321220820992
# 3                                                   None  1399515214039732224
# 4                                                   None  1399515060469383168
# ...                                                  ...                  ...
# 30519                                               None  1396508632364195840
# 30520  [{'type': 'replied_to', 'id': '139649626766519...  1396508393582563328
# 30521  [{'type': 'replied_to', 'id': '139498772591321...  1396508318433112064
# 30522                                               None  1396508316533149696
# 30523                                               None  1396508314377154560
#
#                                      context_annotations               source  \
# 0      [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 1      [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 2      [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 3      [{'domain': {'id': '45', 'name': 'Brand Vertic...   Twitter for iPhone
# 4      [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# ...                                                  ...                  ...
# 30519  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 30520  [{'domain': {'id': '45', 'name': 'Brand Vertic...   Twitter for iPhone
# 30521  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 30522  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 30523  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
#
#                                                 entities  in_reply_to_user_id  \
# 0      {'cashtags': [{'start': 133, 'end': 139, 'tag'...                  NaN
# 1      {'hashtags': [{'start': 13, 'end': 17, 'tag': ...                  NaN
# 2      {'hashtags': [{'start': 243, 'end': 256, 'tag'...         1.369325e+18
# 3      {'cashtags': [{'start': 125, 'end': 131, 'tag'...                  NaN
# 4      {'hashtags': [{'start': 71, 'end': 80, 'tag': ...                  NaN
# ...                                                  ...                  ...
# 30519  {'hashtags': [{'start': 158, 'end': 162, 'tag'...                  NaN
# 30520  {'mentions': [{'start': 0, 'end': 14, 'usernam...         7.432877e+17
# 30521  {'mentions': [{'start': 0, 'end': 10, 'usernam...         1.373252e+18
# 30522  {'hashtags': [{'start': 43, 'end': 47, 'tag': ...                  NaN
# 30523  {'urls': [{'start': 74, 'end': 97, 'url': 'htt...                  NaN
#
#                                       attachments   geo  withheld
# 0                                            None  None       NaN
# 1                                            None  None       NaN
# 2                                            None  None       NaN
# 3      {'media_keys': ['16_1399513023967117315']}  None       NaN
# 4                                            None  None       NaN
# ...                                           ...   ...       ...
# 30519                                        None  None       NaN
# 30520                                        None  None       NaN
# 30521                                        None  None       NaN
# 30522                                        None  None       NaN
# 30523                                        None  None       NaN
#
# [30524 rows x 17 columns]

# %%
data = data.rename(columns={'text': 'corpus'})            
data
# Out:
#       lang reply_settings                                     public_metrics  \
# 0       en       everyone  {'retweet_count': 18, 'reply_count': 1, 'like_...
# 1       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 3       en       everyone  {'retweet_count': 3, 'reply_count': 0, 'like_c...
# 4       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...    ...            ...                                                ...
# 30519   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 30520   en       everyone  {'retweet_count': 0, 'reply_count': 2, 'like_c...
# 30521   en       everyone  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 30522   en       everyone  {'retweet_count': 1, 'reply_count': 3, 'like_c...
# 30523   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                   corpus  possibly_sensitive  \
# 0      Spud4steem | My first participation (June 1, 2...               False
# 1      nice project\n#BSC\n@DinoSour\n#NFT\n\n@NeerJa...               False
# 2      @DinoSourFamily @BinanceChain hopefully this p...               False
# 3      Love in the Time of Chaos\n\n8 editions left, ...               False
# 4      “Navigate the net ” for sale on @withFND! 🌐\n\...               False
# ...                                                  ...                 ...
# 30519  An interesting project with great prospects! A...               False
# 30520  @SpacedPainter @BullishBape No. I didn’t give ...               False
# 30521  @ethernaal Very good project\n\nJoin now my fr...               False
# 30522  Few more weeks i can tell my wife about my #nf...               False
# 30523  I liked  this project \n#NFT #NFTcommunity $WE...               False
#
#                created_at            author_id      conversation_id  \
# 0     2021-05-31 23:59:26  1261710044695052288  1399515896490696704
# 1     2021-05-31 23:58:12           3162743833  1399515589073281024
# 2     2021-05-31 23:57:08  1284100562766557184  1399264273423998976
# 3     2021-05-31 23:56:43  1277381079196893184  1399515214039732224
# 4     2021-05-31 23:56:06           1720966220  1399515060469383168
# ...                   ...                  ...                  ...
# 30519 2021-05-23 16:49:38  1318242727977312256  1396508632364195840
# 30520 2021-05-23 16:48:41   743287719124557824  1396495484538216448
# 30521 2021-05-23 16:48:23  1382143520354435072  1394987725913219072
# 30522 2021-05-23 16:48:23            262938662  1396508316533149696
# 30523 2021-05-23 16:48:22  1222954846002671616  1396508314377154560
#
#                                        referenced_tweets                   id  \
# 0                                                   None  1399515896490696704
# 1      [{'type': 'quoted', 'id': '1398724336345776132'}]  1399515589073281024
# 2      [{'type': 'replied_to', 'id': '139926427342399...  1399515321220820992
# 3                                                   None  1399515214039732224
# 4                                                   None  1399515060469383168
# ...                                                  ...                  ...
# 30519                                               None  1396508632364195840
# 30520  [{'type': 'replied_to', 'id': '139649626766519...  1396508393582563328
# 30521  [{'type': 'replied_to', 'id': '139498772591321...  1396508318433112064
# 30522                                               None  1396508316533149696
# 30523                                               None  1396508314377154560
#
#                                      context_annotations               source  \
# 0      [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 1      [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 2      [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 3      [{'domain': {'id': '45', 'name': 'Brand Vertic...   Twitter for iPhone
# 4      [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# ...                                                  ...                  ...
# 30519  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 30520  [{'domain': {'id': '45', 'name': 'Brand Vertic...   Twitter for iPhone
# 30521  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 30522  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 30523  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
#
#                                                 entities  in_reply_to_user_id  \
# 0      {'cashtags': [{'start': 133, 'end': 139, 'tag'...                  NaN
# 1      {'hashtags': [{'start': 13, 'end': 17, 'tag': ...                  NaN
# 2      {'hashtags': [{'start': 243, 'end': 256, 'tag'...         1.369325e+18
# 3      {'cashtags': [{'start': 125, 'end': 131, 'tag'...                  NaN
# 4      {'hashtags': [{'start': 71, 'end': 80, 'tag': ...                  NaN
# ...                                                  ...                  ...
# 30519  {'hashtags': [{'start': 158, 'end': 162, 'tag'...                  NaN
# 30520  {'mentions': [{'start': 0, 'end': 14, 'usernam...         7.432877e+17
# 30521  {'mentions': [{'start': 0, 'end': 10, 'usernam...         1.373252e+18
# 30522  {'hashtags': [{'start': 43, 'end': 47, 'tag': ...                  NaN
# 30523  {'urls': [{'start': 74, 'end': 97, 'url': 'htt...                  NaN
#
#                                       attachments   geo  withheld
# 0                                            None  None       NaN
# 1                                            None  None       NaN
# 2                                            None  None       NaN
# 3      {'media_keys': ['16_1399513023967117315']}  None       NaN
# 4                                            None  None       NaN
# ...                                           ...   ...       ...
# 30519                                        None  None       NaN
# 30520                                        None  None       NaN
# 30521                                        None  None       NaN
# 30522                                        None  None       NaN
# 30523                                        None  None       NaN
#
# [30524 rows x 17 columns]

# %%
# add stop words
stop_words = stopwords.words('english')
stop_words.append('rt')
stop_words.append('nft')
# stop_words.append('#nft')

# stop words and stemming 
remove_stop = False # set this to True if want to only remove stop words
stem_remove_stop = False # set this to True if want to stem AND remove stop words

def clean_tweet(tweet):
    '''
        Cleans tweet from hashtags, mentions, special characters, html entities, numbers, 
        links, and (optionally) stop words & stemming. Converts text to lower case.
        
        @param tweet - a single tweet (String)
        @return cleaned tweet (String)
    '''
    tweet = str.lower(tweet)
    tweet = ' '.join(re.sub("(@[A-Za-z0-9_]+)|(#[A-Za-z0-9_]+)", " ", tweet).split()) # remove mentions and hashtags
    tweet = re.sub("(http\S+|http)", "", tweet, flags=re.MULTILINE) # remove links
    tweet = re.sub('\&\w+', "", tweet) # remove html entities (example &amp)
    tweet = re.sub('[^a-zA-Z# ]+', ' ', tweet) # make sure tweet is only letters
    
    # TODO - decide whether want to stem and remove stop words (default set to False)
    if remove_stop:
        tweet = remove_stopwords()
    elif stem_remove_stop:
        tweet = stem_and_remove_stopwords()
    else:
        # convert cleaned tweet to list (each tweet being one element in the list)
        tweet = ' '.join([word for word in tweet.split()])
        
    return tweet
    

def remove_stopwords(tweet):
    '''
        Remove stop words from the given tweet.
        
        @param tweet - a single (cleaned) tweet (String)
        @return tweet without stopwords (String)
    '''
    return' '.join([word for word in tweet.split() if word not in stop_words])

def stem_and_remove_stopwords(tweet):
    '''
        Remove stop words from the given tweet and stem the words in the tweet.
        
        @param tweet - a single (cleaned) tweet (String)
        @return stemmed tweet without stopwords (String)
    '''
    
    # TODO: perhaps use Vader's stemming function instead of PorterStemmer
    return ' '.join([PorterStemmer().stem(word=word) for word in tweet.split() if word not in stop_words])


# clean data text line by line
cleaned_text = []
for index in data.index:
    text = data["corpus"][index]
    cleaned_text.append(clean_tweet(text))

cleaned_df = pd.DataFrame(cleaned_text[0:], columns=["cleaned_tweet"])
data['cleaned_tweet'] = cleaned_df['cleaned_tweet']
data
# Out:
#       lang reply_settings                                     public_metrics  \
# 0       en       everyone  {'retweet_count': 18, 'reply_count': 1, 'like_...
# 1       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 3       en       everyone  {'retweet_count': 3, 'reply_count': 0, 'like_c...
# 4       en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...    ...            ...                                                ...
# 30519   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 30520   en       everyone  {'retweet_count': 0, 'reply_count': 2, 'like_c...
# 30521   en       everyone  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 30522   en       everyone  {'retweet_count': 1, 'reply_count': 3, 'like_c...
# 30523   en       everyone  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                   corpus  possibly_sensitive  \
# 0      Spud4steem | My first participation (June 1, 2...               False
# 1      nice project\n#BSC\n@DinoSour\n#NFT\n\n@NeerJa...               False
# 2      @DinoSourFamily @BinanceChain hopefully this p...               False
# 3      Love in the Time of Chaos\n\n8 editions left, ...               False
# 4      “Navigate the net ” for sale on @withFND! 🌐\n\...               False
# ...                                                  ...                 ...
# 30519  An interesting project with great prospects! A...               False
# 30520  @SpacedPainter @BullishBape No. I didn’t give ...               False
# 30521  @ethernaal Very good project\n\nJoin now my fr...               False
# 30522  Few more weeks i can tell my wife about my #nf...               False
# 30523  I liked  this project \n#NFT #NFTcommunity $WE...               False
#
#                created_at            author_id      conversation_id  \
# 0     2021-05-31 23:59:26  1261710044695052288  1399515896490696704
# 1     2021-05-31 23:58:12           3162743833  1399515589073281024
# 2     2021-05-31 23:57:08  1284100562766557184  1399264273423998976
# 3     2021-05-31 23:56:43  1277381079196893184  1399515214039732224
# 4     2021-05-31 23:56:06           1720966220  1399515060469383168
# ...                   ...                  ...                  ...
# 30519 2021-05-23 16:49:38  1318242727977312256  1396508632364195840
# 30520 2021-05-23 16:48:41   743287719124557824  1396495484538216448
# 30521 2021-05-23 16:48:23  1382143520354435072  1394987725913219072
# 30522 2021-05-23 16:48:23            262938662  1396508316533149696
# 30523 2021-05-23 16:48:22  1222954846002671616  1396508314377154560
#
#                                        referenced_tweets                   id  \
# 0                                                   None  1399515896490696704
# 1      [{'type': 'quoted', 'id': '1398724336345776132'}]  1399515589073281024
# 2      [{'type': 'replied_to', 'id': '139926427342399...  1399515321220820992
# 3                                                   None  1399515214039732224
# 4                                                   None  1399515060469383168
# ...                                                  ...                  ...
# 30519                                               None  1396508632364195840
# 30520  [{'type': 'replied_to', 'id': '139649626766519...  1396508393582563328
# 30521  [{'type': 'replied_to', 'id': '139498772591321...  1396508318433112064
# 30522                                               None  1396508316533149696
# 30523                                               None  1396508314377154560
#
#                                      context_annotations               source  \
# 0      [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 1      [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 2      [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 3      [{'domain': {'id': '45', 'name': 'Brand Vertic...   Twitter for iPhone
# 4      [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# ...                                                  ...                  ...
# 30519  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 30520  [{'domain': {'id': '45', 'name': 'Brand Vertic...   Twitter for iPhone
# 30521  [{'domain': {'id': '45', 'name': 'Brand Vertic...      Twitter Web App
# 30522  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
# 30523  [{'domain': {'id': '45', 'name': 'Brand Vertic...  Twitter for Android
#
#                                                 entities  in_reply_to_user_id  \
# 0      {'cashtags': [{'start': 133, 'end': 139, 'tag'...                  NaN
# 1      {'hashtags': [{'start': 13, 'end': 17, 'tag': ...                  NaN
# 2      {'hashtags': [{'start': 243, 'end': 256, 'tag'...         1.369325e+18
# 3      {'cashtags': [{'start': 125, 'end': 131, 'tag'...                  NaN
# 4      {'hashtags': [{'start': 71, 'end': 80, 'tag': ...                  NaN
# ...                                                  ...                  ...
# 30519  {'hashtags': [{'start': 158, 'end': 162, 'tag'...                  NaN
# 30520  {'mentions': [{'start': 0, 'end': 14, 'usernam...         7.432877e+17
# 30521  {'mentions': [{'start': 0, 'end': 10, 'usernam...         1.373252e+18
# 30522  {'hashtags': [{'start': 43, 'end': 47, 'tag': ...                  NaN
# 30523  {'urls': [{'start': 74, 'end': 97, 'url': 'htt...                  NaN
#
#                                       attachments   geo  withheld  \
# 0                                            None  None       NaN
# 1                                            None  None       NaN
# 2                                            None  None       NaN
# 3      {'media_keys': ['16_1399513023967117315']}  None       NaN
# 4                                            None  None       NaN
# ...                                           ...   ...       ...
# 30519                                        None  None       NaN
# 30520                                        None  None       NaN
# 30521                                        None  None       NaN
# 30522                                        None  None       NaN
# 30523                                        None  None       NaN
#
#                                            cleaned_tweet
# 0      spud steem my first participation june powerup...
# 1                                           nice project
# 2      hopefully this project is a success and then i...
# 3      love in the time of chaos editions left tez ea...
# 4                           navigate the net for sale on
# ...                                                  ...
# 30519  an interesting project with great prospects a ...
# 30520  no i didn t give anyone my seed phrase nor wou...
# 30521              very good project join now my friends
# 30522  few more weeks i can tell my wife about my add...
# 30523                          i liked this project weyu
#
# [30524 rows x 18 columns]

# %%
data["cleaned_tweet"]
# Out:
# 0        spud steem my first participation june powerup...
# 1                                             nice project
# 2        hopefully this project is a success and then i...
# 3        love in the time of chaos editions left tez ea...
# 4                             navigate the net for sale on
#                                ...
# 30519    an interesting project with great prospects a ...
# 30520    no i didn t give anyone my seed phrase nor wou...
# 30521                very good project join now my friends
# 30522    few more weeks i can tell my wife about my add...
# 30523                            i liked this project weyu
# Name: cleaned_tweet, Length: 30524, dtype: object

# %%
# # output data text (with their created at time stamps) to txt
# with open('dataout/cleaned_tweets.txt', 'w') as f:
#     for index in data.index:
#         text = "{},{}".format(data["created_at"][index], data["text"][index])
#         f.write(text)
#         f.write('\n')

# %%
# output data text, cleaned_tweets, and createdAt to csv
selected_columns = ["created_at", "corpus", "cleaned_tweet"]
data.to_csv('datain/topic_modelling/cleaned_tweets.csv', columns = selected_columns)
